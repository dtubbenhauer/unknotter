# %% [markdown]
# # Uncrossing / RL unknotting notebook
#
# This notebook was originally written for **Google Colab + Google Drive + GCS**.
# This GitHub version is structured to run **locally** or on **Colab** with minimal edits.
#
# ## Quickstart (local)
# 1. Create a venv and install requirements: `pip install -r requirements.txt`
# 2. Optional environment variables:
#    - `PROJECT_DIR` (defaults to current working directory)
#    - `DATA_DIR`, `OUT_DIR` (defaults to `./data`, `./outputs`)
#    - `GCS_CSV_PATH_MAIN`, etc. (optional)
# 3. Put required local files under `data/` (or override paths via env vars).
#
# ## Quickstart (Colab)
# - Run `pip install -r requirements.txt` in a cell.
# - Set `USE_COLAB_DRIVE=1` if you want automatic Drive mounting.
#
# ---

# %%
# ============================================================
# Colab: RL for simplifying "hard" unknots (CSV→GCS first-col only)
# ============================================================

# --------- 0) Install dependencies ----------

# NOTE: dependency installation moved to requirements.txt (see README).
# --------- 1) Imports & seeds ----------
import os, re, json, random, math, io, gzip, csv, time, itertools, sys
import numpy as np
from typing import List, Iterable, Any, Optional
from dataclasses import dataclass

import gymnasium as gym
from gymnasium import spaces
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.callbacks import EvalCallback
from tqdm.auto import tqdm
import numpy as np

import snappy_manifolds as snappy
from spherogram import Link
import gcsfs

from pathlib import Path
from stable_baselines3 import PPO
from stable_baselines3.common.callbacks import EvalCallback
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.logger import configure

SEED = 42
random.seed(SEED)
np.random.seed(SEED)

# %%
# --------- 2) CSV → GCS reader (first column only) ----------
def _normalize_gcs_path(path: str) -> str:
    # gcsfs usually expects "bucket/path". Accept "gs://bucket/path" as well.
    return path[5:] if path.startswith("gs://") else path

def read_first_column_gcs(path: str,
                          max_lines: int | None = None,
                          has_header: bool = True,
                          delimiter: str | None = None,
                          encoding: str = "utf-8") -> list[str]:
    """
    Read a CSV (optionally .gz) from GCS and return only the first column as strings.
    - path: e.g. "gs://bucket/folder/file.csv" or "bucket/folder/file.csv"
    - max_lines: cap rows returned (after header handling)
    - has_header: skip first row if True
    - delimiter: set explicitly ("," or "\t"); if None, sniff a small sample
    - encoding: for non-gz files
    """
    fs = gcsfs.GCSFileSystem(token="anon")
    path = _normalize_gcs_path(path)
    results: list[str] = []

    def make_reader(fh):
        nonlocal delimiter
        if delimiter is None:
            pos = fh.tell()
            sample = fh.read(4096)
            fh.seek(pos)
            try:
                dialect = csv.Sniffer().sniff(sample)
            except Exception:
                dialect = csv.excel  # default (,)
            return csv.reader(fh, dialect)
        else:
            return csv.reader(fh, delimiter=delimiter)

    if path.lower().endswith(".gz"):
        with fs.open(path, "rb") as fb:
            with gzip.GzipFile(fileobj=fb, mode="rb") as gz:
                with io.TextIOWrapper(gz, encoding=encoding, newline="") as ft:
                    reader = make_reader(ft)
                    if has_header:
                        next(reader, None)
                    for i, row in enumerate(reader):
                        if max_lines is not None and i >= max_lines: break
                        if row:
                            results.append(str(row[0]).strip())
    else:
        with fs.open(path, "rt", encoding=encoding, newline="") as f:
            reader = make_reader(f)
            if has_header:
                next(reader, None)
            for i, row in enumerate(reader):
                if max_lines is not None and i >= max_lines: break
                if row:
                    results.append(str(row[0]).strip())
    return results

# --------- 3) Strict PD/DT parser + cleaner ----------
_RE_DT_PREFIX = re.compile(r'^\s*DT\s*:\s*\[', re.I)
_RE_PDLIST = re.compile(r'^\s*\[\s*(\[\s*\d+(?:\s*,\s*\d+){3}\s*\]\s*,?\s*)+\]\s*$') # [[...], ...]
_RE_XPD       = re.compile(r'[Xx]\s*\[')

def parse_link_strict(s: str) -> Link:
    """
    Accept ONLY PD/DT encodings:
      - 'DT: [ ... ]'
      - PD as nested lists: [[8,3,1,4],[2,6,3,5],...]
      - PD in X[...] blocks: X[a,b,c,d], X[...], ...
    Also unwrap simple JSON/JSONL if it contains 'pd' or 'dt' fields.
    """
    t = s.strip()
    if _RE_DT_PREFIX.match(t):
        return Link(t)
    if _RE_PDLIST.match(t):
    # Convert safely into Python object
        try:
            pd_obj = json.loads(t)  # works if it's valid JSON-like
        except json.JSONDecodeError:
            # fallback for python-style lists with no quotes
            import ast
            pd_obj = ast.literal_eval(t)
        return Link(pd_obj)
    if _RE_XPD.search(t):
        try:
            return Link(t)
        except Exception:
            items = re.findall(r'[Xx]\s*\[([^\]]+)\]', t)
            if not items:
                raise
            blocks = []
            for it in items:
                nums = [int(x.strip()) for x in it.split(',')]
                if len(nums) != 4:
                    raise ValueError("PD block must have 4 integers")
                blocks.append(nums)
            return Link(str(blocks))
    if (t.startswith("{") or t.startswith("[")) and not _RE_PDLIST.match(t):
        try:
            obj = json.loads(t)
            for key in ("pd","PD","pd_code","PD_code","dt","DT"):
                if key in obj:
                    return parse_link_strict(obj[key])
        except Exception:
            pass
    raise ValueError("Not a PD/DT code")

def clean_pd_lines(lines: Iterable[str], max_keep: int | None = None) -> List[str]:
    good = []
    for s in lines:
        try:
            _ = parse_link_strict(s)
            good.append(s.strip())
            if max_keep and len(good) >= max_keep:
                break
        except Exception:
            continue
    return good

# --------- 4) Spherogram helpers ----------
def crossings(link: Link) -> int:
    return len(link.crossings)

def is_trivial_zero(link: Link) -> bool:
    return crossings(link) == 0

def can_reduce_basic(L: Link) -> bool:
    before = crossings(L)
    tmp = Link(L.PD_code())
    changed = tmp.simplify(mode="basic")
    return bool(changed and crossings(tmp) < before)

# --- UPDATED: pure RIII only (no RI/RII), in-place on the given Link ---
def riii_shuffle_only_link(link: Link, k: int, tries_per_move: int = 20):
    """
    Apply up to k random Type-III moves using Spherogram internals
    without triggering any RI/RII simplification. Returns (link, done).
    """
    # lazy import so we don't change your global imports
    from spherogram.links import simplify as _simp
    list_fn  = getattr(_simp, "possible_type_III_moves", None)
    apply_fn = getattr(_simp, "reidemeister_III", None)
    if list_fn is None or apply_fn is None:
        return link, 0

    L = link  # operate in-place
    done = 0
    for _ in range(k):
        moves = list_fn(L)
        if not moves:
            break
        tries = min(tries_per_move, len(moves))
        c0 = crossings(L)
        success = False
        for tri in random.sample(moves, tries):
            apply_fn(L, tri)  # in-place RIII
            if crossings(L) == c0:  # ensure it's a pure RIII (no crossing change)
                success = True
                break
        if not success:
            break
        done += 1
    return L, done

# --------- 5) RL Environment (macro actions with blocking + simple ranking reward) ----------
# The action is MultiDiscrete: [mode, cap]
#   mode ∈ {0:basic, 1:level, 2:pickup, 3:backtrack}
#   cap  ∈ {0..cap_max}

maxstepsdone = 500

# 1) Config
@dataclass
class EnvCfg:
    max_steps: int = maxstepsdone
    step_penalty: float = 0.05           # small time cost
    reward_finish: float = 10.0
    allow_backtrack: bool = True
    cap_max: int = 8
    # Simple mode ranking reward: 0 > 1 > 2 > 3
    # mode_rewards: tuple[float, float, float, float] = (3.0, 2.0, 1.0, 0.0)
    # Reward shaping weights (dense progress)
    w_delta: float = 1.0          # reward per crossing removed
    w_uphill: float = 0.5         # extra penalty per crossing added (beyond losing delta)
    w_potential: float = 0.02     # small push toward low crossings

class SphKnotEnv(gym.Env):
    # ... keep everything else as you have it ...

    def __init__(self, pd_lines: list[str], cfg: EnvCfg):
        super().__init__()
        self.cfg = cfg
        self.pd_lines = pd_lines
        self.rng = random.Random(SEED)

        self.num_actions = 4 if self.cfg.allow_backtrack else 3
        self.action_space = spaces.MultiDiscrete(
            np.array([self.num_actions, self.cfg.cap_max + 1], dtype=np.int64)
        )
        self.obs_dim = 6
        self.observation_space = spaces.Box(
            low=-np.inf, high=np.inf, shape=(self.obs_dim,), dtype=np.float32
        )

        self.L: Optional[Link] = None
        self._steps = 0
        self._last_drop = 0
        self._after_backtrack = False

        # NEW: blocking state (True = blocked). Index by mode.
        self._blocked = [False, False, False, False]

    def _reset_blocks(self):
        self._blocked = [False, False, False, False]

    def _map_blocked_mode(self, mode: int) -> int:
        """If requested mode is blocked, advance to the next unblocked mode (cyclic)."""
        m = mode % self.num_actions
        for _ in range(self.num_actions):
            if not self._blocked[m]:
                return m
            m = (m + 1) % self.num_actions
        # Fallback (shouldn't happen): use backtrack
        return min(3, self.num_actions - 1)

    def reset(self, *, seed=None, options=None):
        super().reset(seed=seed)
        self._steps = 0
        self._last_drop = 0
        self._after_backtrack = False
        self._reset_blocks()
        for _ in range(10):
            s = self.rng.choice(self.pd_lines)
            try:
                self.L = parse_link_strict(s)
                break
            except Exception:
                self.L = None
        if self.L is None:
            self.L = parse_link_strict(self.pd_lines[0])
        return self._obs(), {"crossings": crossings(self.L)}

    def step(self, action):
        # Unpack action
        self._steps += 1
        if isinstance(action, (list, tuple, np.ndarray)):
            mode_req, cap = int(action[0]), int(action[1])
        else:
            mode_req, cap = int(action), 0
        cap = max(0, min(cap, self.cfg.cap_max))

        # Apply blocking: remap to first unblocked mode (cyclic from requested)
        mode = self._map_blocked_mode(mode_req)

        # Context
        c_before = crossings(self.L)

        # Execute chosen (possibly remapped) mode
        if mode == 0:
            self.L.simplify(mode="basic")

        elif mode == 1:
            steps = (cap if cap > 0 else 1)
            self.L.simplify(mode="level", type_III_limit=steps)

        elif mode == 2:
            steps = (cap if cap > 0 else 1)
            self.L.simplify(mode="pickup", type_III_limit=steps)

        elif mode == 3 and self.num_actions == 4:
            steps = (cap if cap > 0 else 1)
            self.L.backtrack(steps=steps, prob_type_1=0.35, prob_type_2=0.65)
            # optional: tiny RIII shuffle is ok to keep or remove; keeping it is fine
            self.L, _ = riii_shuffle_only_link(self.L, min(steps, 2))

        # Post
        c_after = crossings(self.L)
        delta = c_before - c_after  # success iff delta > 0
        self._last_drop = max(delta, 0)

        # --- Reward: simple ranking by mode, small step penalty
        # reward = self.cfg.mode_rewards[mode] - self.cfg.step_penalty
        # --- Reward: dense progress toward fewer crossings
        # delta = c_before - c_after  (positive is good)
        reward = (
            self.cfg.w_delta * delta
            - self.cfg.w_uphill * max(0, -delta)
            - self.cfg.w_potential * c_after
            - self.cfg.step_penalty
        )

        # Finish bonus (unchanged)
        done = False
        if is_trivial_zero(self.L):
            reward += self.cfg.reward_finish
            done = True
        if self._steps >= self.cfg.max_steps:
            done = True

        # --- Blocking logic
        if delta > 0:
            # success -> reset blocks
            self._reset_blocks()
        else:
          if mode == 3:
              self._reset_blocks()
          else:
              # only block if it actually got worse; allow 0-delta tries
              if delta < 0:
                  self._blocked[mode] = True
        # else:
        #     if mode == 3:
        #         # backtrack used -> reset to start of cycle
        #         self._reset_blocks()
        #     else:
        #         # unsuccessful non-backtrack -> block this mode
        #         self._blocked[mode] = True

        # After-backtrack flag (kept for your obs if needed)
        self._after_backtrack = (mode == 3 and self.num_actions == 4)

        info = {
            "crossings": c_after,
            "delta": delta,
            "mode_requested": mode_req,
            "mode_effective": mode,
            "cap": cap,
            "blocked": tuple(self._blocked),
        }
        return self._obs(), reward, done, False, info

# %%
# --------- 2) Environment / paths (local-first; Colab optional) ----------
import os
from pathlib import Path

# Project root: by default current working directory.
# Override: export PROJECT_DIR=/path/to/repo
PROJECT_DIR = Path(os.getenv("PROJECT_DIR", os.getcwd())).resolve()

# Optional: mount Google Drive when running on Colab
if os.getenv("USE_COLAB_DRIVE", "0") == "1":
    try:
        from google.colab import drive  # type: ignore
        drive.mount("/content/drive", force_remount=True)
        # If you want to default to a Drive folder, set PROJECT_DIR explicitly:
        # PROJECT_DIR = Path("/content/drive/MyDrive/crossing-reduction-unknotting").resolve()
    except Exception as e:
        print("[Info] Colab Drive mount skipped:", repr(e))

# Data/outputs (override with env vars if you want)
DATA_DIR = Path(os.getenv("DATA_DIR", str(PROJECT_DIR / "data"))).resolve()
OUT_DIR  = Path(os.getenv("OUT_DIR",  str(PROJECT_DIR / "outputs"))).resolve()
OUT_DIR.mkdir(parents=True, exist_ok=True)

# Local file defaults (put these under data/ or override)
PD_PATH          = Path(os.getenv("PD_PATH",          str(DATA_DIR / "3-16.txt"))).resolve()
SMALL_JONES      = Path(os.getenv("SMALL_JONES",      str(DATA_DIR / "small-jones.txt"))).resolve()
BEST_MODEL_PATH  = Path(os.getenv("BEST_MODEL_PATH",  str(DATA_DIR  / "best_model.zip"))).resolve()
TB_DIR           = Path(os.getenv("TB_DIR",           str(DATA_DIR  / "tb"))).resolve()
TB_DIR.mkdir(parents=True, exist_ok=True)

print("PROJECT_DIR =", PROJECT_DIR)
print("DATA_DIR    =", DATA_DIR)
print("OUT_DIR     =", OUT_DIR)
print("PD_PATH     =", PD_PATH)
print("SMALL_JONES =", SMALL_JONES)
print("BEST_MODEL  =", BEST_MODEL_PATH)

# If you start Jupyter from the repo root, this is correct:
BASE = Path.cwd() / "data"

LOCAL_RANDOM  = BASE / "random_diagrams.csv"
LOCAL_RANDOM2 = BASE / "random_diagrams_2.csv"
LOCAL3        = BASE / "very_hard_unknots_2.csv"

HAS_HEADER_RANDOM = True  # set to False if no header row

print("BASE:", BASE)
print("LOCAL_RANDOM:", LOCAL_RANDOM, "exists?", LOCAL_RANDOM.exists())
print("LOCAL_RANDOM2:", LOCAL_RANDOM2, "exists?", LOCAL_RANDOM2.exists())
print("LOCAL3:", LOCAL3, "exists?", LOCAL3.exists())
# Out:
# PROJECT_DIR = /home/dani/uncrossing-number/notebooks
# DATA_DIR    = /home/dani/uncrossing-number/notebooks/data
# OUT_DIR     = /home/dani/uncrossing-number/notebooks/outputs
# PD_PATH     = /home/dani/uncrossing-number/notebooks/data/3-16.txt
# SMALL_JONES = /home/dani/uncrossing-number/notebooks/data/small-jones.txt
# BEST_MODEL  = /home/dani/uncrossing-number/notebooks/data/best_model.zip
# BASE: /home/dani/uncrossing-number/notebooks/data
# LOCAL_RANDOM: /home/dani/uncrossing-number/notebooks/data/random_diagrams.csv exists? True
# LOCAL_RANDOM2: /home/dani/uncrossing-number/notebooks/data/random_diagrams_2.csv exists? True
# LOCAL3: /home/dani/uncrossing-number/notebooks/data/very_hard_unknots_2.csv exists? True

# %%
# --------- 6) Load mixed CSVs from GCS (first column only), then shuffle ----------
# Files:
GCS_CSV_PATH_MAIN = "gs://gdm-unknotting/hard_unknots.csv"         # large file
GCS_CSV_PATH_VERY = "gs://gdm-unknotting/very_hard_unknots.csv"
GCS_CSV_PATH_RANDOM = "gs://gdm-unknotting/random_diagrams.csv"    # much smaller file
GCS_CSV_PATH_RANDOM2 = "gs://gdm-unknotting/random_diagrams_2.csv"

# Parsing options (set per file if needed)
HAS_HEADER_MAIN = True
HAS_HEADER_VERY = True
HAS_HEADER_RANDOM = True
DELIMITER_MAIN  = None   # None = auto-sniff; else set "," or "\t"
DELIMITER_VERY  = None
DELIMITER_RANDOM  = None
MAX_ROWS_MAIN   = 385   # cap from the big file
SEED            = 42        # for reproducible shuffle

# 1) Read first column from all CSVs
raw_main = read_first_column_gcs(
    GCS_CSV_PATH_MAIN,
    max_lines=MAX_ROWS_MAIN,
    has_header=HAS_HEADER_MAIN,
    delimiter=DELIMITER_MAIN,
    encoding="utf-8",
)
raw_very = read_first_column_gcs(
    GCS_CSV_PATH_VERY,
    max_lines=None,                 # load the small file completely
    has_header=HAS_HEADER_VERY,
    delimiter=DELIMITER_VERY,
    encoding="utf-8",
)

def read_first_col_local(path: str, has_header: bool = True, encoding: str = "utf-8") -> list[str]:
    out = []
    with open(path, "r", encoding=encoding, newline="") as f:
        rdr = csv.reader(f)
        if has_header:
            next(rdr, None)
        for row in rdr:
            if row:
                out.append(row[0].strip())
    return out

raw_random = read_first_col_local(LOCAL_RANDOM, has_header=HAS_HEADER_RANDOM, encoding="utf-8")
raw_random2 = read_first_col_local(LOCAL_RANDOM2, has_header=HAS_HEADER_RANDOM, encoding="utf-8")
raw3 = read_first_col_local(LOCAL3, has_header=HAS_HEADER_RANDOM, encoding="utf-8")

print(f"[MAIN @ GCS] {len(raw_main)} rows (capped {MAX_ROWS_MAIN}).")
print(f"[VERY @ GCS] {len(raw_very)} rows.")
print(f"[RANDOM @ local] {len(raw_random)} rows.")
print(f"[RANDOM2 @ local] {len(raw_random2)} rows.")
print(f"[RAW3 @ local] {len(raw3)} rows.")

# 2) Concatenate (VERY_HARD first so they are guaranteed included), then clean to PD/DT
combined_raw = list(raw_very) + list(raw_main) + list(raw_random) + list(raw_random2) + list(raw3)
pd_lines = clean_pd_lines(combined_raw, max_keep=None)
assert pd_lines, "No valid PD/DT lines after cleaning—check the CSV columns or delimiters."

# 3) Shuffle for training (reproducible)
rng = random.Random(SEED)
rng.shuffle(pd_lines)

print(f"[Data] Kept {len(pd_lines)} PD/DT strings after strict filtering and shuffling.")
# (Optionally, deduplicate; uncomment if needed)
# pd_lines = list(dict.fromkeys(pd_lines))
# print(f"[Data] After de-duplication: {len(pd_lines)} PD/DT strings.")

#pd_lines_train = pd_lines[:TRAIN_ROWS]
#pd_lines_test = pd_lines[TRAIN_ROWS+1:MAX_ROWS]

def _obs_patch(self):
    c = crossings(self.L)
    try:
        comps = len(self.L.link_components)
    except Exception:
        comps = 1
    tmp = Link(self.L.PD_code())
    reduced = tmp.simplify(mode="basic")
    can_reduce = 1.0 if (reduced and crossings(tmp) < c) else 0.0
    recent = 1.0 if getattr(self, "_last_drop", 0) > 0 else 0.0
    return np.array([c, comps, self._steps, can_reduce, recent, 1.0], dtype=np.float32)

# Monkey-patch if needed
SphKnotEnv._obs = getattr(SphKnotEnv, "_obs", _obs_patch)

# --------- 7) Build envs ----------
# (Optional) If you want backtrack available in this run, set allow_backtrack=True here:
cfg = EnvCfg(max_steps=maxstepsdone, allow_backtrack=True)  # flip to True later if helpful
def make_env():
    return SphKnotEnv(pd_lines, cfg)

env = make_env()
vec_env = DummyVecEnv([lambda: make_env()])

obs, info = env.reset()
print("[Env] obs:", obs, "start crossings:", info["crossings"])
# Out:
# [MAIN @ GCS] 385 rows (capped 385).
# [VERY @ GCS] 385 rows.
# [RANDOM @ local] 770 rows.
# [RANDOM2 @ local] 770 rows.
# [RAW3 @ local] 385 rows.
# [Data] Kept 2695 PD/DT strings after strict filtering and shuffling.
# [Env] obs: [35.  1.  0.  0.  0.  1.] start crossings: 35

# %%
import os

# The BASE directory is defined in hnGBP8uScIAl
print(f"Listing contents of: {BASE}/")

# List all files and directories in the BASE path
if os.path.exists(BASE):
    for root, dirs, files in os.walk(BASE):
        # Only show immediate children of BASE for brevity unless user specifies more depth
        if root == BASE:
            print("  Directories:")
            for d in dirs:
                print(f"    - {d}/")
            print("  Files:")
            for f in files:
                print(f"    - {f}")
            break # Only list the top level of BASE for now
else:
    print(f"The directory '{BASE}' does not exist. Please check the BASE path.")
# Out:
# Listing contents of: /home/dani/uncrossing-number/notebooks/data/

# %%
# --------- 7) Train PPO ----------

from stable_baselines3.common.callbacks import CheckpointCallback

# === Envs ===
vec_env  = DummyVecEnv([lambda: make_env()])
eval_env = DummyVecEnv([lambda: make_env()])

seed = random.randint(1, 100)
SEED = random.seed(seed)
TOTAL_STEPS = 12288*1

# === Load existing model or start fresh ===
if os.path.exists(BEST_MODEL_PATH):
    print(f"[Resume] Loading {BEST_MODEL_PATH}")
    model = PPO.load(BEST_MODEL_PATH, env=vec_env, device="auto")
    model.set_logger(configure(str(TB_DIR), ["stdout", "tensorboard"]))
else:
    print("[Fresh] Starting new PPO model")
    model = PPO(
        "MlpPolicy",
        env,
        learning_rate=lambda p: 3e-4 * p, # linear decay
        n_steps=2048,
        batch_size=256,
        n_epochs=10,
        gamma=0.995,
        gae_lambda=0.97,
        clip_range=0.2,
        ent_coef=0.01,
        vf_coef=0.5,
        max_grad_norm=0.5,
        tensorboard_log=TB_DIR,
        seed=SEED,
    )

# === Callbacks ===
# EvalCallback will now save directly as /MyDrive/crossing-reduction/best_model.zip
eval_cb = EvalCallback(
    eval_env,
    best_model_save_path=BASE,
    eval_freq=10000,
    n_eval_episodes=1,
    deterministic=True,
)
# (optional) periodic checkpoints — also in flat folder
ckpt_cb = CheckpointCallback(save_freq=50000, save_path=BASE, name_prefix="ppo")

# === Train (continues if loaded) ===
model.learn(
    total_timesteps=TOTAL_STEPS,
    callback=[eval_cb, ckpt_cb],
    reset_num_timesteps=False,
    progress_bar=False, # Set to False to avoid LiveError in Colab
)

# === Save snapshot ===
final_path = f"{BASE}/ppo_knot_rl_spherogram_continued.zip"
model.save(final_path)
print(f"[Train] Saved -> {final_path}")
# Out:
# [Resume] Loading /home/dani/uncrossing-number/notebooks/data/best_model.zip
# Logging to /home/dani/uncrossing-number/notebooks/data/tb
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 403      |
# |    ep_rew_mean     | -142     |
# | time/              |          |
# |    fps             | 377      |
# |    iterations      | 1        |
# |    time_elapsed    | 5        |
# |    total_timesteps | 152048   |
# ---------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 403           |
# |    ep_rew_mean          | -142          |
# | time/                   |               |
# |    fps                  | 346           |
# |    iterations           | 2             |
# |    time_elapsed         | 11            |
# |    total_timesteps      | 154096        |
# | train/                  |               |
# |    approx_kl            | 0.00025145215 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.97         |
# |    explained_variance   | 0.082         |
# |    learning_rate        | 1.89e-05      |
# |    loss                 | 69.2          |
# |    n_updates            | 710           |
# |    policy_gradient_loss | -0.000524     |
# |    value_loss           | 147           |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 403          |
# |    ep_rew_mean          | -142         |
# | time/                   |              |
# |    fps                  | 352          |
# |    iterations           | 3            |
# |    time_elapsed         | 17           |
# |    total_timesteps      | 156144       |
# | train/                  |              |
# |    approx_kl            | 1.751905e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.01        |
# |    explained_variance   | 0.189        |
# |    learning_rate        | 1.51e-05     |
# |    loss                 | 62.3         |
# |    n_updates            | 720          |
# |    policy_gradient_loss | -0.000117    |
# |    value_loss           | 88.3         |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 403           |
# |    ep_rew_mean          | -142          |
# | time/                   |               |
# |    fps                  | 324           |
# |    iterations           | 4             |
# |    time_elapsed         | 25            |
# |    total_timesteps      | 158192        |
# | train/                  |               |
# |    approx_kl            | 1.0584277e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.96         |
# |    explained_variance   | 0.169         |
# |    learning_rate        | 1.14e-05      |
# |    loss                 | 34.7          |
# |    n_updates            | 730           |
# |    policy_gradient_loss | -0.000142     |
# |    value_loss           | 60            |
# -------------------------------------------
# /home/dani/uncrossing-number/.venv/lib/python3.12/site-packages/stable_baselines3/common/evaluation.py:70: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# Eval num_timesteps=160000, episode_reward=-188.00 +/- 0.00
# Episode length: 500.00 +/- 0.00
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 500          |
# |    mean_reward          | -188         |
# | time/                   |              |
# |    total_timesteps      | 160000       |
# | train/                  |              |
# |    approx_kl            | 9.657233e-07 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.06        |
# |    explained_variance   | 0.121        |
# |    learning_rate        | 7.57e-06     |
# |    loss                 | 59           |
# |    n_updates            | 740          |
# |    policy_gradient_loss | -5.3e-05     |
# |    value_loss           | 105          |
# ------------------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 403      |
# |    ep_rew_mean     | -142     |
# | time/              |          |
# |    fps             | 318      |
# |    iterations      | 5        |
# |    time_elapsed    | 32       |
# |    total_timesteps | 160240   |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 403          |
# |    ep_rew_mean          | -142         |
# | time/                   |              |
# |    fps                  | 326          |
# |    iterations           | 6            |
# |    time_elapsed         | 37           |
# |    total_timesteps      | 162288       |
# | train/                  |              |
# |    approx_kl            | 8.543779e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.98        |
# |    explained_variance   | 0.177        |
# |    learning_rate        | 3.79e-06     |
# |    loss                 | 27.7         |
# |    n_updates            | 750          |
# |    policy_gradient_loss | -0.000113    |
# |    value_loss           | 63.1         |
# ------------------------------------------
# [Train] Saved -> /home/dani/uncrossing-number/notebooks/data/ppo_knot_rl_spherogram_continued.zip

# %%
OUT_DIR = BASE

# %%
#K1 = [[1,9,2,8],[3,11,4,10],[5,13,6,12],[7,1,8,14],[9,3,10,2],[11,5,12,4],[13,7,14,6]] This is 7_1
#K2 = [[8,1,9,2],[10,3,11,4],[12,5,13,6],[14,7,1,8],[2,9,3,10],[4,11,5,12],[6,13,7,14]] This is the mirror of 7_1

#K1 = [[2,8,3,7],[4,10,5,9],[6,2,7,1],[8,4,9,3],[10,6,1,5]] # This is 5_1
#K2 = [[1,10,2,11],[3,13,4,12],[5,15,6,14],[7,1,8,16],[9,2,10,3],[11,9,12,8],[13,5,14,4],[15,7,16,6]] # This is 8_2

K1 = [[4,2,5,1],[8,6,1,5],[6,3,7,4],[2,7,3,8]] # This is 4_1
K2 = [[1,13,2,12],[3,11,4,10],[5,17,6,16],[7,15,8,14],[9,1,10,18],[11,3,12,2],[13,5,14,4],[15,7,16,6],[17,9,18,8]] # This is 9_10

# ---------- connected sum (your build uses .connected_sum) ----------
def connected_sum_pd(PD1, PD2, simplify=True):
    L1, L2 = Link(PD1), Link(PD2)
    out = L1.connected_sum(L2)  # returns new Link or mutates in place
    L = out if out is not None else L1
    if simplify and hasattr(L, "simplify"):
        try:
            L.simplify()
        except TypeError:
            pass
    return [list(q) for q in L.PD_code()]  # normalize to list-of-lists

T = connected_sum_pd(K1,K2)
T
# Out:
# [[11, 17, 12, 16],
#  [15, 13, 16, 12],
#  [13, 18, 14, 19],
#  [17, 14, 18, 15],
#  [19, 5, 20, 4],
#  [21, 3, 22, 2],
#  [23, 9, 24, 8],
#  [25, 7, 0, 6],
#  [1, 11, 2, 10],
#  [3, 21, 4, 20],
#  [5, 23, 6, 22],
#  [7, 25, 8, 24],
#  [9, 1, 10, 0]]

# %%
# -----------------------------------------
# Randomize the knot T via backtrack + RIII
# -----------------------------------------

# Parameters (re-using from cell EhrCjVQukWfN for consistency)
NUM_VARIANTS_FOR_T = 100    # how many randomised diagrams for T
BACKTRACK_STEPS_MIN = 6    # min steps per randomisation
BACKTRACK_STEPS_MAX = 6   # max steps per randomisation
RIII_STEPS_MAX      = 25    # as in your env, min(steps, 2)
GEN_T_OUT_PATH      = f"{BASE}/generated_T_pd_backtrack.txt"

print("Randomising knot T:")

generated_T_pd_lines = []  # JSON PD list strings

# T is already a list of quads, convert to Link object
L0_T = Link(T)

for v in range(NUM_VARIANTS_FOR_T):
    # fresh copy from PD code so we don't mutate L0_T
    pd0 = L0_T.PD_code()
    # handle both list and PDCode cases
    if isinstance(pd0, list):
        L = Link(pd0)
    else:
        L = Link([[int(getattr(e, "label", e)) for e in vtx] for vtx in pd0])

    # choose random number of backtrack steps
    steps = random.randint(BACKTRACK_STEPS_MIN, BACKTRACK_STEPS_MAX)

    # your usual "add crossings and shuffle" move:
    L.backtrack(steps=steps, prob_type_1=0.35, prob_type_2=0.65)
    L, _ = riii_shuffle_only_link(L, min(steps, RIII_STEPS_MAX))

    # now extract PD as list-of-quads
    pd_obj = L.PD_code()
    if isinstance(pd_obj, list):
        quads = [[int(x) for x in quad] for quad in pd_obj]
    else:
        quads = [[int(getattr(edge, "label", edge)) for edge in vtx] for vtx in pd_obj]

    pd_str_new = json.dumps(quads)
    generated_T_pd_lines.append(pd_str_new)
    print(f"  variant {v:02d}: steps={steps}, crossings_final={len(quads)}")

print(f"\nGenerated {len(generated_T_pd_lines)} randomised PDs from T.")

# -----------------------------------------
# Save new PDs to a file (JSON PD list format)
# -----------------------------------------
with open(GEN_T_OUT_PATH, "w") as f:
    for line in generated_T_pd_lines:
        f.write(line + "\n")

print(f"Wrote {len(generated_T_pd_lines)} PD lines for T to {GEN_T_OUT_PATH}")

# Optional: peek at the generated PDs for T
print(f"\nPeeking at the first {min(NUM_VARIANTS_FOR_T, len(generated_T_pd_lines))} generated PDs for T:\n")
for i, pd_str in enumerate(generated_T_pd_lines[:NUM_VARIANTS_FOR_T]):
    quads = json.loads(pd_str)
    try:
        L = Link(quads)
        c = len(L.crossings)
    except Exception as e:
        L = None
        c = "?"
    print(f"[{i}] crossings = {c}")
    print(f"    {pd_str}")
# Out:
# Randomising knot T:
#   variant 00: steps=6, crossings_final=22
#   variant 01: steps=6, crossings_final=22
#   variant 02: steps=6, crossings_final=25
#   variant 03: steps=6, crossings_final=24
#   variant 04: steps=6, crossings_final=23
#   variant 05: steps=6, crossings_final=24
#   variant 06: steps=6, crossings_final=25
#   variant 07: steps=6, crossings_final=25
#   variant 08: steps=6, crossings_final=22
#   variant 09: steps=6, crossings_final=22
#   variant 10: steps=6, crossings_final=23
#   variant 11: steps=6, crossings_final=21
#   variant 12: steps=6, crossings_final=22
#   variant 13: steps=6, crossings_final=23
#   variant 14: steps=6, crossings_final=23
#   variant 15: steps=6, crossings_final=25
#   variant 16: steps=6, crossings_final=22
#   variant 17: steps=6, crossings_final=23
#   variant 18: steps=6, crossings_final=21
#   variant 19: steps=6, crossings_final=22
#   variant 20: steps=6, crossings_final=23
#   variant 21: steps=6, crossings_final=24
#   variant 22: steps=6, crossings_final=23
#   variant 23: steps=6, crossings_final=22
#   variant 24: steps=6, crossings_final=24
#   variant 25: steps=6, crossings_final=23
#   variant 26: steps=6, crossings_final=22
#   variant 27: steps=6, crossings_final=22
#   variant 28: steps=6, crossings_final=24
#   variant 29: steps=6, crossings_final=24
#   variant 30: steps=6, crossings_final=23
#   variant 31: steps=6, crossings_final=23
#   variant 32: steps=6, crossings_final=24
#   variant 33: steps=6, crossings_final=23
#   variant 34: steps=6, crossings_final=23
#   variant 35: steps=6, crossings_final=24
#   variant 36: steps=6, crossings_final=22
#   variant 37: steps=6, crossings_final=22
#   variant 38: steps=6, crossings_final=22
#   variant 39: steps=6, crossings_final=23
#   variant 40: steps=6, crossings_final=24
#   variant 41: steps=6, crossings_final=23
#   variant 42: steps=6, crossings_final=23
#   variant 43: steps=6, crossings_final=25
#   variant 44: steps=6, crossings_final=21
#   variant 45: steps=6, crossings_final=23
#   variant 46: steps=6, crossings_final=22
#   variant 47: steps=6, crossings_final=22
#   variant 48: steps=6, crossings_final=23
#   variant 49: steps=6, crossings_final=24
#   variant 50: steps=6, crossings_final=22
#   variant 51: steps=6, crossings_final=22
#   variant 52: steps=6, crossings_final=22
#   variant 53: steps=6, crossings_final=22
#   variant 54: steps=6, crossings_final=22
#   variant 55: steps=6, crossings_final=20
#   variant 56: steps=6, crossings_final=22
#   variant 57: steps=6, crossings_final=24
#   variant 58: steps=6, crossings_final=22
#   variant 59: steps=6, crossings_final=25
#   variant 60: steps=6, crossings_final=22
#   variant 61: steps=6, crossings_final=23
#   variant 62: steps=6, crossings_final=24
#   variant 63: steps=6, crossings_final=21
#   variant 64: steps=6, crossings_final=25
#   variant 65: steps=6, crossings_final=22
#   variant 66: steps=6, crossings_final=24
#   variant 67: steps=6, crossings_final=21
#   variant 68: steps=6, crossings_final=23
#   variant 69: steps=6, crossings_final=24
#   variant 70: steps=6, crossings_final=25
#   variant 71: steps=6, crossings_final=21
#   variant 72: steps=6, crossings_final=24
#   variant 73: steps=6, crossings_final=21
#   variant 74: steps=6, crossings_final=24
#   variant 75: steps=6, crossings_final=22
#   variant 76: steps=6, crossings_final=24
#   variant 77: steps=6, crossings_final=24
#   variant 78: steps=6, crossings_final=21
#   variant 79: steps=6, crossings_final=24
#   variant 80: steps=6, crossings_final=23
#   variant 81: steps=6, crossings_final=20
#   variant 82: steps=6, crossings_final=22
#   variant 83: steps=6, crossings_final=22
#   variant 84: steps=6, crossings_final=23
#   variant 85: steps=6, crossings_final=24
#   variant 86: steps=6, crossings_final=22
#   variant 87: steps=6, crossings_final=23
#   variant 88: steps=6, crossings_final=23
#   variant 89: steps=6, crossings_final=23
#   variant 90: steps=6, crossings_final=24
#   variant 91: steps=6, crossings_final=25
#   variant 92: steps=6, crossings_final=22
#   variant 93: steps=6, crossings_final=23
#   variant 94: steps=6, crossings_final=23
#   variant 95: steps=6, crossings_final=24
#   variant 96: steps=6, crossings_final=22
#   variant 97: steps=6, crossings_final=24
#   variant 98: steps=6, crossings_final=22
#   variant 99: steps=6, crossings_final=23
#
# Generated 100 randomised PDs from T.
# Wrote 100 PD lines for T to /home/dani/uncrossing-number/notebooks/data/generated_T_pd_backtrack.txt
#
# Peeking at the first 100 generated PDs for T:
#
# [0] crossings = 22
#     [[23, 17, 24, 16], [17, 23, 18, 22], [21, 14, 22, 15], [15, 18, 16, 19], [13, 37, 14, 36], [9, 39, 10, 38], [7, 29, 8, 28], [1, 35, 2, 34], [41, 25, 42, 24], [37, 11, 38, 10], [35, 9, 36, 8], [29, 7, 30, 6], [27, 1, 28, 0], [19, 20, 20, 21], [33, 3, 34, 2], [32, 3, 33, 4], [11, 13, 12, 12], [40, 40, 41, 39], [26, 43, 27, 0], [25, 43, 26, 42], [31, 5, 32, 4], [30, 5, 31, 6]]
# [1] crossings = 22
#     [[25, 19, 26, 18], [19, 23, 20, 22], [21, 16, 22, 17], [17, 20, 18, 21], [15,
def read_pd_lines_from_file(path: str, max_lines: int | None = None):
    """Read non-empty lines from a local PD file and return the first `max_lines`."""
    with open(path, "r") as f:
        lines = [ln.strip() for ln in f if ln.strip()]
    return lines[:max_lines]

def parse_pd_line_to_list(line: str):
    """
    Parse either
      - JSON PD lists: '[[1,5,2,4],[3,1,4,6],...]'
      - or PD[X[1,5,2,4], X[3,1,4,6], ...]
    into [[a,b,c,d], ...].
    """
    t = line.strip()

    # 1) Try JSON / Python list first
    try:
        obj = json.loads(t)
        if isinstance(obj, list) and obj and isinstance(obj[0], (list, tuple)):
            quads = []
            for quad in obj:
                if len(quad) != 4:
                    raise ValueError(f"PD block must have 4 integers, got {quad!r}")
                quads.append([int(x) for x in quad])
            return quads
    except Exception:
        pass  # not JSON, fall back to PD[X[...]] format

    # 2) Fallback: PD[X[...], X[...], ...] format
    items = re.findall(r'[Xx]\s*\[([^\]]+)\]', t)
    if not items:
        raise ValueError(f"No X[...] blocks found in line: {line!r}")

    quads = []
    for it in items:
        nums = [int(x.strip()) for x in it.split(',')]
        if len(nums) != 4:
            raise ValueError(f"PD block must have 4 integers, got {nums!r}")
        quads.append(nums)
    return quads

# Assuming PD_PATH2 is defined elsewhere, e.g., in an earlier cell
# PD_PATH2 = f"{BASE}/generated_T_pd_backtrack.txt"
raw_pd_lines = read_pd_lines_from_file(PD_PATH2, max_lines=NUM_VARIANTS_FOR_T)
print("First PD lines from PD_PATH2:")
for i, s in enumerate(raw_pd_lines):
    print(f"  [{i}] {s}")

pd_lists = [parse_pd_line_to_list(s) for s in raw_pd_lines]
print("\nParsed as PD lists (lengths):", [len(p) for p in pd_lists])

# ================================# 2) Crossing flip + PD variants# ================================
def flip_crossing_quad(quad):
    """[a,b,c,d] -> [b,c,d,a]"""
    a, b, c, d = quad
    return [b, c, d, a]

def pd_list_to_str(pd_list):
    """
    Stringify to something parse_link_strict accepts.
    This produces '[[1,5,2,4],[3,1,4,6],...]' which matches the
    _RE_PDLIST branch in parse_link_strict.
    """
    import json # Ensure json is imported if not globally available
    return json.dumps(pd_list)

def generate_changed_pds(pd_list, k):
    """
    Yield all PD-lists obtained by flipping exactly k crossings,
    in lexicographic order on crossing indices.
    """
    n = len(pd_list)
    for idxs in itertools.combinations(range(n), k):
        idxs_set = set(idxs)
        new_pd = []
        for i, quad in enumerate(pd_list):
            if i in idxs_set:
                new_pd.append(flip_crossing_quad(quad))
            else:
                new_pd.append(list(quad))
        yield idxs, new_pd

# ================================# 3) RL wrapper: run agent on one PD# ================================
# Load your best model (avoid reloading if already in memory)
try:
    model
except NameError:
    model = PPO.load(BEST_MODEL_PATH, device="cpu")
    print("\n[Model] Loaded PPO model from:", BEST_MODEL_PATH)

def make_single_env(pd_list, cfg: EnvCfg):
    """
    Build a DummyVecEnv whose SphKnotEnv always starts from this single PD.
    """
    pd_str = pd_list_to_str(pd_list)
    pd_lines_single = [pd_str]

    def _make():
        return SphKnotEnv(pd_lines_single, cfg)

    return DummyVecEnv([_make])

def run_unknotter_on_pd(pd_list, model, cfg: EnvCfg,
                        episodes: int = 3, label: str = "",
                        return_best_pd: bool = False):
    """
    Run the PPO agent on a single PD (wrapped into a single-knot env).

    Default return (backwards-compatible):
        (success: bool, best_crossings: int)

    If return_best_pd=True, returns:
        (success: bool, best_crossings: int, best_pd_list: list[list[int]])

    Here, best_pd_list is the *best* (fewest crossings) PD encountered during the rollouts.
    """
    vec_env = make_single_env(pd_list, cfg)

    success = False
    best_crossings_global = len(pd_list)
    best_pd_global = [list(q) for q in pd_list]

    for ep in range(episodes):
        obs = vec_env.reset()  # no info at vec level

        # Track best within this episode
        best_crossings_ep = best_crossings_global
        best_pd_ep = best_pd_global

        for step in range(cfg.max_steps):
            action, _ = model.predict(obs, deterministic=True)
            obs, rewards, dones, infos = vec_env.step(action)

            info = infos[0]
            cr = info.get("crossings", None)

            # Pull current PD directly from the underlying env (DummyVecEnv → envs[0])
            try:
                cur_pd = [list(q) for q in vec_env.envs[0].L.PD_code()]
            except Exception:
                cur_pd = None

            if cr is not None and cr < best_crossings_ep and cur_pd is not None:
                best_crossings_ep = cr
                best_pd_ep = cur_pd

            # success criterion: crossings == 0
            if cr == 0:
                success = True
                if cur_pd is not None:
                    best_crossings_ep = 0
                    best_pd_ep = cur_pd
                break

            if dones[0]:
                break

        # Update global best across episodes
        if best_crossings_ep < best_crossings_global:
            best_crossings_global = best_crossings_ep
            best_pd_global = best_pd_ep

        if success:
            break

    vec_env.close()

    if return_best_pd:
        return success, best_crossings_global, best_pd_global
    return success, best_crossings_global

# ================================# 3b) Helpers: (optional) extra simplify + SnapPy identification# ================================
def simplify_pd_basic(pd_list, rounds: int = 5):
    """Run a few rounds of Spherogram basic simplification and return a (possibly) smaller PD."""
    try:
        L = Link(pd_list)
        for _ in range(rounds):
            before = len(L.crossings)
            try:
                L.simplify(mode="basic")
            except TypeError:
                L.simplify()
            after = len(L.crossings)
            if after >= before:
                break
        return [list(q) for q in L.PD_code()]
    except Exception:
        # If anything goes wrong, just return the input
        return [list(q) for q in pd_list]

def identify_knot_snappy(pd_list):
    """Try to identify the knot/link represented by pd_list using SnapPy."""
    # Try via Spherogram → exterior() (preferred when available)
    try:
        L = Link(pd_list)
        M = L.exterior()
        try:
            name = M.identify()
        except Exception:
            name = None
        return name, M
    except Exception:
        pass

    # Fallback: SnapPy Link directly
    try:
        Ls = snappy.Link(pd_list)
        M = Ls.exterior()
        try:
            name = M.identify()
        except Exception:
            name = None
        return name, M
    except Exception as e:
        return None, None

# ================================# 4) Untangling number search# ================================
def compute_untangling_number(pd_list,
                              model,
                              cfg: EnvCfg,
                              max_changes: int | None = None,
                              episodes: int = 3):
    """
    Search for minimal k \u2265 1 such that flipping k crossings
    yields a diagram which the RL machine can unknot.

    Returns (k, idxs) where
      - k is the untangling number (int or None)
      - idxs is the tuple of crossing indices to flip (or None)
    """
    n = len(pd_list)
    if max_changes is None:
        max_changes = n

    for k in range(1, max_changes + 1):
        for idxs, new_pd in generate_changed_pds(pd_list, k):
            success, _ = run_unknotter_on_pd(new_pd, model, cfg, episodes=episodes)
# %%
original_pd_list = f"{BASE}/generated_T_pd_backtrack.txt"  # file with generated JSON PD lists

# %%
import itertools

# --- ANSI colors (safe defaults) ---
RESET = "\033[0m"
RED   = "\033[91m"
GREEN = "\033[92m"
YELLOW= "\033[93m"

# Require OUT_DIR to be defined by your Drive/paths cell
import os, json
if "OUT_DIR" not in globals():
    raise NameError("OUT_DIR is not defined. Please run the Drive/paths cell first.")

flips = 1  # Number of crossings to flip (now: exactly one)

all_possible_modified_knots_info = []

# Assuming pd_lists contains the original PD lists to work with
for original_pd_list in pd_lists:
    n_crossings = len(original_pd_list)

    # Ensure there are enough crossings to perform the requested number of flips
    if n_crossings < flips:
        print(f"Skipping PD list with only {n_crossings} crossings (less than {flips} required flips).")
        continue

    # Generate all unique combinations of 'flips' distinct crossing indices
    for flipped_indices_combo in itertools.combinations(range(n_crossings), flips):
        flipped_indices = sorted(list(flipped_indices_combo))  # Ensure sorted for consistent reporting

        flipped_pd_list = []
        for i, quad in enumerate(original_pd_list):
            if i in flipped_indices:
                flipped_pd_list.append(flip_crossing_quad(quad))
            else:
                flipped_pd_list.append(list(quad))  # Ensure a deep copy

        all_possible_modified_knots_info.append({
            "original_pd_list": original_pd_list,
            "flipped_pd_list": flipped_pd_list,
            "flipped_indices": tuple(flipped_indices)
        })

print(f"Generated {len(all_possible_modified_knots_info)} all possible modified knot variants (combinations of {flips} flips).")

print("\nEvaluating RL model on all possible modified knots:")

results_summary_all_possible = []

for i, knot_info in enumerate(all_possible_modified_knots_info):
    original_pd_list = knot_info["original_pd_list"]
    flipped_pd_list = knot_info["flipped_pd_list"]
    flipped_indices = knot_info["flipped_indices"]

    initial_crossings = len(original_pd_list)

    print(f"\n--- Knot variant {i+1}/{len(all_possible_modified_knots_info)} ---")
    print(f"  Original crossings: {initial_crossings}")
    print(f"  Flipped indices: {flipped_indices}")

    # Run the unknotter on the flipped PD list (and keep the best PD it finds)
    success, min_crossings_found, best_pd_list = run_unknotter_on_pd(
        flipped_pd_list,
        model,
        cfg,
        episodes=1,  # keep fast for evaluation
        label=f"Knot {i+1} (flips {flipped_indices})",
        return_best_pd=True,
    )

    print(f"  Min crossings found: {min_crossings_found}")

    results_summary_all_possible.append({
        "knot_index": i + 1,
        "original_crossings": initial_crossings,
        "flipped_indices": flipped_indices,
        "rl_unknot_success": success,
        "min_crossings_found": min_crossings_found,
        "best_pd_list": best_pd_list,
        "flipped_pd_list": flipped_pd_list,
    })

print("\n=================== Final Summary (All Possible Flips) ===================")
for res in results_summary_all_possible:
    status_color = RED if res["rl_unknot_success"] else RESET
    print(
        f"{status_color}Knot {res['knot_index']}: "
        f"Original Crossings={res['original_crossings']}, "
        f"Flipped Indices={res['flipped_indices']}, "
        f"RL Unknot Success={res['rl_unknot_success']}, "
        f"Min Crossings Found={res['min_crossings_found']}"
        f"{RESET}"
    )
print("========================================================================")

# ============================
# Write minimal-PD outputs to file (for later diagnosis)
# ============================
os.makedirs(OUT_DIR, exist_ok=True)

# Deterministic name (overwrite on rerun)
out_path = os.path.join(OUT_DIR, f"min_pd_results_flips{flips}.jsonl")

with open(out_path, "w") as f:
    for res in results_summary_all_possible:
        rec = dict(res)
        rec["flipped_indices"] = list(rec["flipped_indices"])  # JSON-friendly
        f.write(json.dumps(rec) + "\n")

print(f"\nWrote minimal-PD results to: {out_path}")
# Out:
# Generated 2288 all possible modified knot variants (combinations of 1 flips).
#
# Evaluating RL model on all possible modified knots:
#
# --- Knot variant 1/2288 ---
#   Original crossings: 22
#   Flipped indices: (0,)
#   Min crossings found: 9
#
# --- Knot variant 2/2288 ---
#   Original crossings: 22
#   Flipped indices: (1,)
#   Min crossings found: 9
#
# --- Knot variant 3/2288 ---
#   Original crossings: 22
#   Flipped indices: (2,)
#   Min crossings found: 9
#
# --- Knot variant 4/2288 ---
#   Original crossings: 22
#   Flipped indices: (3,)
#   Min crossings found: 9
#
# --- Knot variant 5/2288 ---
#   Original crossings: 22
#   Flipped indices: (4,)
#   Min crossings found: 11
#
# --- Knot variant 6/2288 ---
#   Original crossings: 22
#   Flipped indices: (5,)
#   Min crossings found: 11
#
# --- Knot variant 7/2288 ---
#   Original crossings: 22
#   Flipped indices: (6,)
#   Min crossings found: 11
#
# --- Knot variant 8/2288 ---
#   Original crossings: 22
#   Flipped indices: (7,)
#   Min crossings found: 11
#
# --- Knot variant 9/2288 ---
#   Original crossings: 22
#   Flipped indices: (8,)
#   Min crossings found: 11
#
# --- Knot variant 10/2288 ---
#   Original crossings: 22
#   Flipped indices: (9,)
#   Min crossings found: 11
#
# --- Knot variant 11/2288 ---
#   Original crossings: 22
#   Flipped indices: (10,)
#   Min crossings found: 11
#
# --- Knot variant 12/2288 ---
#   Original crossings: 22
#   Flipped indices: (11,)
#   Min crossings found: 11
#
# --- Knot variant 13/2288 ---
#   Original crossings: 22
#   Flipped indices: (12,)
#   Min crossings found: 11
#
# --- Knot variant 14/2288 ---
#   Original crossings: 22
#   Flipped indices: (13,)
#   Min crossings found: 13
#
# --- Knot variant 15/2288 ---
#   Original crossings: 22
#   Flipped indices: (14,)
#   Min crossings found: 11
#
# --- Knot variant 16/2288 ---
#   Original crossings: 22
#   Flipped indices: (15,)
#   Min crossings found: 15
#
# --- Knot variant 17/2288 ---
#   Original crossings: 22
#   Flipped indices: (16,)
#   Min crossings found: 13
#
# --- Knot variant 18/2288 ---
#   Original crossings: 22
#   Flipped indices: (17,)
#   Min crossings found: 13
#
# --- Knot variant 19/2288 ---
#   Original crossings: 22
#   Flipped indices: (18,)
#   Min crossings found: 15
#
# --- Knot variant 20/2288 ---
#   Original crossings: 22
#   Flipped indices: (19,)
#   Min crossings found: 11
#
# --- Knot variant 21/2288 ---
#   Original crossings: 22
#   Flipped indices: (20,)
#   Min crossings found: 11
#
# --- Knot variant 22/2288 ---
#   Original crossings: 22
#   Flipped indices: (21,)
#   Min crossings found: 15
#
# --- Knot variant 23/2288 ---
#   Original crossings: 22
#   Flipped indices: (0,)
#   Min crossings found: 9
#
# --- Knot variant 24/2288 ---
#   Original crossings: 22
#   Flipped indices: (1,)
#   Min crossings found: 9
#
# --- Knot variant 25/2288 ---
#   Original crossings: 22
#   Flipped indices: (2,)
#   Min crossings found: 9
#
# --- Knot variant 26/2288 ---
#   Original crossings: 22
#   Flipped indices: (3,)
#   Min crossings found: 9
#
# --- Knot variant 27/2288 ---
#   Original crossings: 22
#   Flipped indices: (4,)
#   Min crossings found: 11
#
# --- Knot variant 28/2288 ---
#   Original crossings: 22
#   Flipped indices: (5,)
#   Min crossings found: 11
#
# --- Knot variant 29/2288 ---
#   Original crossings: 22
#   Flipped indices: (6,)
#   Min crossings found: 11
#
# --- Knot variant 30/2288 ---
#   Original crossings: 22
#   Flipped indices: (7,)
#   Min crossings found: 11
#
# --- Knot variant 31/2288 ---
#   Original crossings: 22
#   Flipped indices: (8,)
#   Min crossings found: 11
#
# --- Knot variant 32/2288 ---
#   Original crossings: 22
#   Flipped indices: (9,)
#   Min crossings found: 11
#
# --- Knot variant 33/2288 ---
#   Original crossings: 22
#   Flipped indices: (10,)
#   Min crossings found: 11
#
# --- Knot variant 34/2288 ---
#   Original crossings: 22
#   Flipped indices: (11,)
#   Min crossings found: 11
#
# --- Knot variant 35/2288 ---
#   Original crossings: 22
#   Flipped indices: (12,)
#   Min crossings found: 11
#
# --- Knot variant 36/2288 ---
#   Original crossings: 22
#   Flipped indices: (13,)
#   Min crossings found: 13
#
# --- Knot variant 37/2288 ---
#   Original crossings: 22
#   Flipped indices: (14,)
#   Min crossings found: 15
#
# --- Knot variant 38/2288 ---
#   Original crossings: 22
#   Flipped indices: (15,)
#   Min crossings found: 11
#
# --- Knot variant 39/2288 ---
#   Original crossings: 22
#   Flipped indices: (16,)
#   Min crossings found: 15
#
# --- Knot variant 40/2288 ---
#   Original crossings: 22
#   Flipped indices: (17,)
#   Min crossings found: 11
#
# --- Knot variant 41/2288 ---
#   Original crossings: 22
#   Flipped indices: (18,)
#   Min crossings found: 15
#
# --- Knot variant 42/2288 ---
#   Original crossings: 22
#   Flipped indices: (19,)
#   Min crossings found: 11
#
# --- Knot variant 43/2288 ---
#   Original crossings: 22
#   Flipped indices: (20,)
#   Min crossings found: 13
#
# --- Knot variant 44/2288 ---
#   Original crossings: 22
#   Flipped indices: (21,)
#   Min crossings found: 13
#
# --- Knot variant 45/2288 ---
#   Original crossings: 25
#   Flipped indices: (0,)
#   Min crossings found: 9
#
# --- Knot variant 46/2288 ---
#   Original crossings: 25
#   Flipped indices: (1,)
#   Min crossings found: 9
#
# --- Knot variant 47/2288 ---
#   Original crossings: 25
#   Flipped indices: (2,)
#   Min crossings found: 9
#
# --- Knot variant 48/2288 ---
#   Original crossings: 25
#   Flipped indices: (3,)
#   Min crossings found: 9
#
# --- Knot variant 49/2288 ---
#   Original crossings: 25
#   Flipped indices: (4,)
#   Min crossings found: 11
#
# --- Knot variant 50/2288 ---
#   Original crossings: 25
#   Flipped indices: (5,)
#   Min crossings found: 11
#
# --- Knot variant 51/2288 ---
#   Original crossings: 25
#   Flipped indices: (6,)
#   Min crossings found: 11
#
# --- Knot variant 52/2288 ---
#   Original crossings: 25
#   Flipped indices: (7,)
#   Min crossings found: 11
#
# --- Knot variant 53/2288 ---
#   Original crossings: 25
#   Flipped indices: (8,)
#   Min crossings found: 11
#
# --- Knot variant 54/2288 ---
#   Original crossings: 25
#   Flipped indices: (9,)
#   Min crossings found: 11
#
# --- Knot variant 55/2288 ---
#   Original crossings: 25
#   Flipped indices: (10,)
#   Min crossings found: 11
#
# --- Knot variant 56/2288 ---
#   Original crossings: 25
#   Flipped indices: (11,)
#   Min crossings found: 11
#
# --- Knot variant 57/2288 ---
#   Original crossings: 25
#   Flipped indices: (12,)
#   Min crossings found: 11
#
# --- Knot variant 58/2288 ---
#   Original crossings: 25
#   Flipped indices: (13,)
#   Min crossings found: 11
#
# --- Knot variant 59/2288 ---
#   Original crossings: 25
#   Flipped indices: (14,)
#   Min crossings found: 15
#
# --- Knot variant 60/2288 ---
#   Original crossings: 25
#   Flipped indices: (15,)
#   Min crossings found: 11
#
# --- Knot variant 61/2288 ---
#   Original crossings: 25
#   Flipped indices: (16,)
#   Min crossings found: 15
#
# --- Knot variant 62/2288 ---
#   Original crossings: 25
#   Flipped indices: (17,)
#   Min crossings found: 11
#
# --- Knot variant 63/2288 ---
#   Original crossings: 25
#   Flipped indices: (18,)
#   Min crossings found: 15
#
# --- Knot variant 64/2288 ---
#   Original crossings: 25
#   Flipped indices: (19,)
#   Min crossings found: 11
#
# --- Knot variant 65/2288 ---
#   Original crossings: 25
#   Flipped indices: (20,)
#   Min crossings found: 15
#
# --- Knot variant 66/2288 ---
#   Original crossings: 25
#   Flipped indices: (21,)
#   Min crossings found: 11
#
# --- Knot variant 67/2288 ---
#   Original crossings: 25
#   Flipped indices: (22,)
#   Min crossings found: 15
#
# --- Knot variant 68/2288 ---
#   Original crossings: 25
#   Flipped indices: (23,)
#   Min crossings found: 15
#
# --- Knot variant 69/2288 ---
#   Original crossings: 25
#   Flipped indices: (24,)
#   Min crossings found: 9
#
# --- Knot variant 70/2288 ---
#   Original crossings: 24
#   Flipped indices: (0,)
#   Min crossings found: 9
#
# --- Knot variant 71/2288 ---
#   Original crossings: 24
#   Flipped indices: (1,)
#   Min crossings found: 9
#
# --- Knot variant 72/2288 ---
#   Original crossings: 24
#   Flipped indices: (2,)
#   Min crossings found: 9
#
# --- Knot variant 73/2288 ---
#   Original crossings: 24
#   Flipped indices: (3,)
#   Min crossings found: 9
#
# --- Knot variant 74/2288 ---
#   Original crossings: 24
#   Flipped indices: (4,)
#   Min crossings found: 11
#
# --- Knot variant 75/2288 ---
#   Original crossings: 24
#   Flipped indices: (5,)
#   Min crossings found: 11
#
# --- Knot variant 76/2288 ---
#   Original crossings: 24
#   Flipped indices: (6,)
#   Min crossings found: 11
#
# --- Knot variant 77/2288 ---
#   Original crossings: 24
#   Flipped indices: (7,)
#   Min crossings found: 11
#
# --- Knot variant 78/2288 ---
#   Original crossings: 24
#   Flipped indices: (8,)
#   Min crossings found: 11
#
# --- Knot variant 79/2288 ---
#   Original crossings: 24
#   Flipped indices: (9,)
#   Min crossings found: 11
#
# --- Knot variant 80/2288 ---
#   Original crossings: 24
#   Flipped indices: (10,)
#   Min crossings found: 11
#
# --- Knot variant 81/2288 ---
#   Original crossings: 24
#   Flipped indices: (11,)
#   Min crossings found: 11
#
# --- Knot variant 82/2288 ---
#   Original crossings: 24
#   Flipped indices: (12,)
#   Min crossings found: 11
#
# --- Knot variant 83/2288 ---
#   Original crossings: 24
#   Flipped indices: (13,)
#   Min crossings found: 11
#
# --- Knot variant 84/2288 ---
#   Original crossings: 24
#   Flipped indices: (14,)
#   Min crossings found: 15
#
# --- Knot variant 85/2288 ---
#   Original crossings: 24
#   Flipped indices: (15,)
#   Min crossings found: 13
#
# --- Knot variant 86/2288 ---
#   Original crossings: 24
#   Flipped indices: (16,)
#   Min crossings found: 15
#
# --- Knot variant 87/2288 ---
#   Original crossings: 24
#   Flipped indices: (17,)
#   Min crossings found: 9
#
# --- Knot variant 88/2288 ---
#   Original crossings: 24
#   Flipped indices: (18,)
#   Min crossings found: 11
#
# --- Knot variant 89/2288 ---
#   Original crossings: 24
#   Flipped indices: (19,)
#   Min crossings found: 15
#
# --- Knot variant 90/2288 ---
#   Original crossings: 24
#   Flipped indices: (20,)
#   Min crossings found: 13
#
# --- Knot variant 91/2288 ---
#   Original crossings: 24
#   Flipped indices: (21,)
#   Min crossings found: 16
#
# --- Knot variant 92/2288 ---
#   Original crossings: 24
#   Flipped indices: (22,)
#   Min crossings found: 15
#
# --- Knot variant 93/2288 ---
#   Original crossings: 24
#   Flipped indices: (23,)
#   Min crossings found: 13
#
# --- Knot variant 94/2288 ---
#   Original crossings: 23
#   Flipped indices: (0,)
#   Min crossings found: 9
#
# --- Knot variant 95/2288 ---
#   Original crossings: 23
#   Flipped indices: (1,)
#   Min crossings found: 9
#
# --- Knot variant 96/2288 ---
#   Original crossings: 23
#   Flipped indices: (2,)
#   Min crossings found: 9
#
# --- Knot variant 97/2288 ---
#   Original crossings: 23
#   Flipped indices: (3,)
#   Min crossings found: 9
#
# --- Knot variant 98/2288 ---
#   Original crossings: 23
#   Flipped indices: (4,)
#   Min crossings found: 11
#
# --- Knot variant 99/2288 ---
#   Original crossings: 23
#   Flipped indices: (5,)
#   Min crossings found: 11
#
# --- Knot variant 100/2288 ---
#   Original crossings: 23
#   Flipped indices: (6,)
#   Min crossings found: 11
#
# --- Knot variant 101/2288 ---
#   Original crossings: 23
#   Flipped indices: (7,)
#   Min crossings found: 11
#
# --- Knot variant 102/2288 ---
#   Original crossings: 23
#   Flipped indices: (8,)
#   Min crossings found: 11
#
# --- Knot variant 103/2288 ---
#   Original crossings: 23
#   Flipped indices: (9,)
#   Min crossings found: 11
#
# --- Knot variant 104/2288 ---
#   Original crossings: 23
#   Flipped indices: (10,)
#   Min crossings found: 11
#
# --- Knot variant 105/2288 ---
#   Original crossings: 23
#   Flipped indices: (11,)
#   Min crossings found: 11
#
# --- Knot variant 106/2288 ---
#   Original crossings: 23
#   Flipped indices: (12,)
#   Min crossings found: 11
#
# --- Knot variant 107/2288 ---
#   Original crossings: 23
#   Flipped indices: (13,)
#   Min crossings found: 13
#
# --- Knot variant 108/2288 ---
#   Original crossings: 23
#   Flipped indices: (14,)
#   Min crossings found: 15
#
# --- Knot variant 109/2288 ---
#   Original crossings: 23
#   Flipped indices: (15,)
#   Min crossings found: 15
#
# --- Knot variant 110/2288 ---
#   Original crossings: 23
#   Flipped indices: (16,)
#   Min crossings found: 11
#
# --- Knot variant 111/2288 ---
#   Original crossings: 23
#   Flipped indices: (17,)
#   Min crossings found: 15
#
# --- Knot variant 112/2288 ---
#   Original crossings: 23
#   Flipped indices: (18,)
#   Min crossings found: 16
#
# --- Knot variant 113/2288 ---
#   Original crossings: 23
#   Flipped indices: (19,)
#   Min crossings found: 13
#
# --- Knot variant 114/2288 ---
#   Original crossings: 23
#   Flipped indices: (20,)
#   Min crossings found: 15
#
# --- Knot variant 115/2288 ---
#   Original crossings: 23
#   Flipped indices: (21,)
#   Min crossings found: 15
#
# --- Knot variant 116/2288 ---
#   Original crossings: 23
#   Flipped indices: (22,)
#   Min crossings found: 13
#
# --- Knot variant 117/2288 ---
#   Original crossings: 24
#   Flipped indices: (0,)
#   Min crossings found: 9
#
# --- Knot variant 118/2288 ---
#   Original crossings: 24
#   Flipped indices: (1,)
#   Min crossings found: 9
#
# --- Knot variant 119/2288 ---
#   Original crossings: 24
#   Flipped indices: (2,)
#   Min crossings found: 9
#
# --- Knot variant 120/2288 ---
#   Original crossings: 24
#   Flipped indices: (3,)
#   Min crossings found: 9
#
# --- Knot variant 121/2288 ---
#   Original crossings: 24
#   Flipped indices: (4,)
#   Min crossings found: 11
#
# --- Knot variant 122/2288 ---
#   Original crossings: 24
#   Flipped indices: (5,)
#   Min crossings found: 11
#
# --- Knot variant 123/2288 ---
#   Original crossings: 24
#   Flipped indices: (6,)
#   Min crossings found: 11
#
# --- Knot variant 124/2288 ---
#   Original crossings: 24
#   Flipped indices: (7,)
#   Min crossings found: 11
#
# --- Knot variant 125/2288 ---
#   Original crossings: 24
#   Flipped indices: (8,)
#   Min crossings found: 11
#
# --- Knot variant 126/2288 ---
#   Original crossings: 24
#   Flipped indices: (9,)
#   Min crossings found: 11
#
# --- Knot variant 127/2288 ---
#   Original crossings: 24
#   Flipped indices: (10,)
#   Min crossings found: 11
#
# --- Knot variant 128/2288 ---
#   Original crossings: 24
#   Flipped indices: (11,)
#   Min crossings found: 11
#
# --- Knot variant 129/2288 ---
#   Original crossings: 24
#   Flipped indices: (12,)
#   Min crossings found: 11
#
# --- Knot variant 130/2288 ---
#   Original crossings: 24
#   Flipped indices: (13,)
#   Min crossings found: 15
#
# --- Knot variant 131/2288 ---
#   Original crossings: 24
#   Flipped indices: (14,)
#   Min crossings found: 11
#
# --- Knot variant 132/2288 ---
#   Original crossings: 24
#   Flipped indices: (15,)
#   Min crossings found: 11
#
# --- Knot variant 133/2288 ---
#   Original crossings: 24
#   Flipped indices: (16,)
#   Min crossings found: 15
#
# --- Knot variant 134/2288 ---
#   Original crossings: 24
#   Flipped indices: (17,)
#   Min crossings found: 11
#
# --- Knot variant 135/2288 ---
#   Original crossings: 24
#   Flipped indices: (18,)
#   Min crossings found: 15
#
# --- Knot variant 136/2288 ---
#   Original crossings: 24
#   Flipped indices: (19,)
#   Min crossings found: 13
#
# --- Knot variant 137/2288 ---
#   Original crossings: 24
#   Flipped indices: (20,)
#   Min crossings found: 13
#
# --- Knot variant 138/2288 ---
#   Original crossings: 24
#   Flipped indices: (21,)
#   Min crossings found: 15
#
# --- Knot variant 139/2288 ---
#   Original crossings: 24
#   Flipped indices: (22,)
#   Min crossings found: 11
#
# --- Knot variant 140/2288 ---
#   Original crossings: 24
#   Flipped indices: (23,)
#   Min crossings found: 15
#
# --- Knot variant 141/2288 ---
#   Original crossings: 25
#   Flipped indices: (0,)
#   Min crossings found: 9
#
# --- Knot variant 142/2288 ---
#   Original crossings: 25
#   Flipped indices: (1,)
#   Min crossings found: 9
#
# --- Knot variant 143/2288 ---
#   Original crossings: 25
#   Flipped indices: (2,)
#   Min crossings found: 9
#
# --- Knot variant 144/2288 ---
#   Original crossings: 25
#   Flipped indices: (3,)
#   Min crossings found: 9
#
# --- Knot variant 145/2288 ---
#   Original crossings: 25
#   Flipped indices: (4,)
#   Min crossings found: 11
#
# --- Knot variant 146/2288 ---
#   Original crossings: 25
#   Flipped indices: (5,)
#   Min crossings found: 11
#
# --- Knot variant 147/2288 ---
#   Original crossings: 25
#   Flipped indices: (6,)
#   Min crossings found: 11
#
# --- Knot variant 148/2288 ---
#   Original crossings: 25
#   Flipped indices: (7,)
#   Min crossings found: 11
#
# --- Knot variant 149/2288 ---
#   Original crossings: 25
#   Flipped indices: (8,)
#   Min crossings found: 11
#
# --- Knot variant 150/2288 ---
#   Original crossings: 25
#   Flipped indices: (9,)
#   Min crossings found: 11
#
# --- Knot variant 151/2288 ---
#   Original crossings: 25
#   Flipped indices: (10,)
#   Min crossings found: 11
#
# --- Knot variant 152/2288 ---
#   Original crossings: 25
#   Flipped indices: (11,)
#   Min crossings found: 11
#
# --- Knot variant 153/2288 ---
#   Original crossings: 25
#   Flipped indices: (12,)
#   Min crossings found: 11
#
# --- Knot variant 154/2288 ---
#   Original crossings: 25
#   Flipped indices: (13,)
#   Min crossings found: 15
#
# --- Knot variant 155/2288 ---
#   Original crossings: 25
#   Flipped indices: (14,)
#   Min crossings found: 11
#
# --- Knot variant 156/2288 ---
#   Original crossings: 25
#   Flipped indices: (15,)
#   Min crossings found: 9
#
# --- Knot variant 157/2288 ---
#   Original crossings: 25
#   Flipped indices: (16,)
#   Min crossings found: 15
#
# --- Knot variant 158/2288 ---
#   Original crossings: 25
#   Flipped indices: (17,)
#   Min crossings found: 9
#
# --- Knot variant 159/2288 ---
#   Original crossings: 25
#   Flipped indices: (18,)
#   Min crossings found: 15
#
# --- Knot variant 160/2288 ---
#   Original crossings: 25
#   Flipped indices: (19,)
#   Min crossings found: 9
#
# --- Knot variant 161/2288 ---
#   Original crossings: 25
#   Flipped indices: (20,)
#   Min crossings found: 15
#
# --- Knot variant 162/2288 ---
#   Original crossings: 25
#   Flipped indices: (21,)
#   Min crossings found: 11
#
# --- Knot variant 163/2288 ---
#   Original crossings: 25
#   Flipped indices: (22,)
#   Min crossings found: 15
#
# --- Knot variant 164/2288 ---
#   Original crossings: 25
#   Flipped indices: (23,)
#   Min crossings found: 9
#
# --- Knot variant 165/2288 ---
#   Original crossings: 25
#   Flipped indices: (24,)
#   Min crossings found: 15
#
# --- Knot variant 166/2288 ---
#   Original crossings: 25
#   Flipped indices: (0,)
#   Min crossings found: 9
#
# --- Knot variant 167/2288 ---
#   Original crossings: 25
#   Flipped indices: (1,)
#   Min crossings found: 9
#
# --- Knot variant 168/2288 ---
#   Original crossings: 25
#   Flipped indices: (2,)
#   Min crossings found: 9
#
# --- Knot variant 169/2288 ---
#   Original crossings: 25
#   Flipped indices: (3,)
#   Min crossings found: 9
#
# --- Knot variant 170/2288 ---
#   Original crossings: 25
#   Flipped indices: (4,)
#   Min crossings found: 11
#
# --- Knot variant 171/2288 ---
#   Original crossings: 25
#   Flipped indices: (5,)
#   Min crossings found: 11
#
# --- Knot variant 172/2288 ---
#   Original crossings: 25
#   Flipped indices: (6,)
#   Min crossings found: 11
#
# --- Knot variant 173/2288 ---
#   Original crossings: 25
#   Flipped indices: (7,)
#   Min crossings found: 11
#
# --- Knot variant 174/2288 ---
#   Original crossings: 25
#   Flipped indices: (8,)
#   Min crossings found: 11
#
# --- Knot variant 175/2288 ---
#   Original crossings: 25
#   Flipped indices: (9,)
#   Min crossings found: 11
#
# --- Knot variant 176/2288 ---
#   Original crossings: 25
#   Flipped indices: (10,)
#   Min crossings found: 11
#
# --- Knot variant 177/2288 ---
#   Original crossings: 25
#   Flipped indices: (11,)
#   Min crossings found: 11
#
# --- Knot variant 178/2288 ---
#   Original crossings: 25
#   Flipped indices: (12,)
#   Min crossings found: 11
#
# --- Knot variant 179/2288 ---
#   Original crossings: 25
#   Flipped indices: (13,)
#   Min crossings found: 9
#
# --- Knot variant 180/2288 ---
#   Original crossings: 25
#   Flipped indices: (14,)
#   Min crossings found: 15
#
# --- Knot variant 181/2288 ---
#   Original crossings: 25
#   Flipped indices: (15,)
#   Min crossings found: 15
#
# --- Knot variant 182/2288 ---
#   Original crossings: 25
#   Flipped indices: (16,)
#   Min crossings found: 11
#
# --- Knot variant 183/2288 ---
#   Original crossings: 25
#   Flipped indices: (17,)
#   Min crossings found: 15
#
# --- Knot variant 184/2288 ---
#   Original crossings: 25
#   Flipped indices: (18,)
#   Min crossings found: 9
#
# --- Knot variant 185/2288 ---
#   Original crossings: 25
#   Flipped indices: (19,)
#   Min crossings found: 15
#
# --- Knot variant 186/2288 ---
#   Original crossings: 25
#   Flipped indices: (20,)
#   Min crossings found: 11
#
# --- Knot variant 187/2288 ---
#   Original crossings: 25
#   Flipped indices: (21,)
#   Min crossings found: 9
#
# --- Knot variant 188/2288 ---
#   Original crossings: 25
#   Flipped indices: (22,)
#   Min crossings found: 15
#
# --- Knot variant 189/2288 ---
#   Original crossings: 25
#   Flipped indices: (23,)
#   Min crossings found: 9
#
# --- Knot variant 190/2288 ---
#   Original crossings: 25
#   Flipped indices: (24,)
#   Min crossings found: 15
#
# --- Knot variant 191/2288 ---
#   Original crossings: 22
#   Flipped indices: (0,)
#   Min crossings found: 9
#
# --- Knot variant 192/2288 ---
#   Original crossings: 22
#   Flipped indices: (1,)
#   Min crossings found: 9
#
# --- Knot variant 193/2288 ---
#   Original crossings: 22
#   Flipped indices: (2,)
#   Min crossings found: 9
#
# --- Knot variant 194/2288 ---
#   Original crossings: 22
#   Flipped indices: (3,)
#   Min crossings found: 9
#
# --- Knot variant 195/2288 ---
#   Original crossings: 22
#   Flipped indices: (4,)
#   Min crossings found: 11
#
# --- Knot variant 196/2288 ---
#   Original crossings: 22
#   Flipped indices: (5,)
#   Min crossings found: 11
#
# --- Knot variant 197/2288 ---
#   Original crossings: 22
#   Flipped indices: (6,)
#   Min crossings found: 11
#
# --- Knot variant 198/2288 ---
#   Original crossings: 22
#   Flipped indices: (7,)
#   Min crossings found: 11
#
# --- Knot variant 199/2288 ---
#   Original crossings: 22
#   Flipped indices: (8,)
#   Min crossings found: 11
#
# --- Knot variant 200/2288 ---
#   Original crossings: 22
#   Flipped indices: (9,)
#   Min crossings found: 11
#
# --- Knot variant 201/2288 ---
#   Original crossings: 22
#   Flipped indices: (10,)
#   Min crossings found: 11
#
# --- Knot variant 202/2288 ---
#   Original crossings: 22
#   Flipped indices: (11,)
#   Min crossings found: 11
#
# --- Knot variant 203/2288 ---
#   Original crossings: 22
#   Flipped indices: (12,)
#   Min crossings found: 11
#
# --- Knot variant 204/2288 ---
#   Original crossings: 22
#   Flipped indices: (13,)
#   Min crossings found: 13
#
# --- Knot variant 205/2288 ---
#   Original crossings: 22
#   Flipped indices: (14,)
#   Min crossings found: 13
#
# --- Knot variant 206/2288 ---
#   Original crossings: 22
#   Flipped indices: (15,)
#   Min crossings found: 13
#
# --- Knot variant 207/2288 ---
#   Original crossings: 22
#   Flipped indices: (16,)
#   Min crossings found: 16
#
# --- Knot variant 208/2288 ---
#   Original crossings: 22
#   Flipped indices: (17,)
#   Min crossings found: 15
#
# --- Knot variant 209/2288 ---
#   Original crossings: 22
#   Flipped indices: (18,)
#   Min crossings found: 11
#
# --- Knot variant 210/2288 ---
#   Original crossings: 22
#   Flipped indices: (19,)
#   Min crossings found: 13
#
# --- Knot variant 211/2288 ---
#   Original crossings: 22
#   Flipped indices: (20,)
#   Min crossings found: 15
#
# --- Knot variant 212/2288 ---
#   Original crossings: 22
#   Flipped indices: (21,)
#   Min crossings found: 11
#
# --- Knot variant 213/2288 ---
#   Original crossings: 22
#   Flipped indices: (0,)
#   Min crossings found: 9
#
# --- Knot variant 214/2288 ---
#   Original crossings: 22
#   Flipped indices: (1,)
#   Min crossings found: 9
#
# --- Knot variant 215/2288 ---
#   Original crossings: 22
#   Flipped indices: (2,)
#   Min crossings found: 9
#
# --- Knot variant 216/2288 ---
#   Original crossings: 22
#   Flipped indices: (3,)
#   Min crossings found: 9
#
# --- Knot variant 217/2288 ---
#   Original crossings: 22
#   Flipped indices: (4,)
#   Min crossings found: 11
#
# --- Knot variant 218/2288 ---
#   Original crossings: 22
#   Flipped indices: (5,)
#   Min crossings found: 11
#
# --- Knot variant 219/2288 ---
#   Original crossings: 22
#   Flipped indices: (6,)
#   Min crossings found: 11
#
# --- Knot variant 220/2288 ---
#   Original crossings: 22
#   Flipped indices: (7,)
#   Min crossings found: 11
#
# --- Knot variant 221/2288 ---
#   Original crossings: 22
#   Flipped indices: (8,)
#   Min crossings found: 11
#
# --- Knot variant 222/2288 ---
#   Original crossings: 22
#   Flipped indices: (9,)
#   Min crossings found: 11
#
# --- Knot variant 223/2288 ---
#   Original crossings: 22
#   Flipped indices: (10,)
#   Min crossings found: 11
#
# --- Knot variant 224/2288 ---
#   Original crossings: 22
#   Flipped indices: (11,)
#   Min crossings found: 11
#
# --- Knot variant 225/2288 ---
#   Original crossings: 22
#   Flipped indices: (12,)
#   Min crossings found: 11
#
# --- Knot variant 226/2288 ---
#   Original crossings: 22
#   Flipped indices: (13,)
#   Min crossings found: 13
#
# --- Knot variant 227/2288 ---
#   Original crossings: 22
#   Flipped indices: (14,)
#   Min crossings found: 11
#
# --- Knot variant 228/2288 ---
#   Original crossings: 22
#   Flipped indices: (15,)
#   Min crossings found: 15
#
# --- Knot variant 229/2288 ---
#   Original crossings: 22
#   Flipped indices: (16,)
#   Min crossings found: 13
#
# --- Knot variant 230/2288 ---
#   Original crossings: 22
#   Flipped indices: (17,)
#   Min crossings found: 13
#
# --- Knot variant 231/2288 ---
#   Original crossings: 22
#   Flipped indices: (18,)
#   Min crossings found: 16
#
# --- Knot variant 232/2288 ---
#   Original crossings: 22
#   Flipped indices: (19,)
#   Min crossings found: 13
#
# --- Knot variant 233/2288 ---
#   Original crossings: 22
#   Flipped indices: (20,)
#   Min crossings found: 11
#
# --- Knot variant 234/2288 ---
#   Original crossings: 22
#   Flipped indices: (21,)
#   Min crossings found: 15
#
# --- Knot variant 235/2288 ---
#   Original crossings: 23
#   Flipped indices: (0,)
#   Min crossings found: 9
#
# --- Knot variant 236/2288 ---
#   Original crossings: 23
#   Flipped indices: (1,)
#   Min crossings found: 9
#
# --- Knot variant 237/2288 ---
#   Original crossings: 23
#   Flipped indices: (2,)
#   Min crossings found: 9
#
# --- Knot variant 238/2288 ---
#   Original crossings: 23
#   Flipped indices: (3,)
#   Min crossings found: 9
#
# --- Knot variant 239/2288 ---
#   Original crossings: 23
#   Flipped indices: (4,)
#   Min crossings found: 11
#
# --- Knot variant 240/2288 ---
#   Original crossings: 23
#   Flipped indices: (5,)
#   Min crossings found: 11
#
# --- Knot variant 241/2288 ---
#   Original crossings: 23
#   Flipped indices: (6,)
#   Min crossings found: 11
#
# --- Knot variant 242/2288 ---
#   Original crossings: 23
#   Flipped indices: (7,)
#   Min crossings found: 11
#
# --- Knot variant 243/2288 ---
#   Original crossings: 23
#   Flipped indices: (8,)
#   Min crossings found: 11
#
# --- Knot variant 244/2288 ---
#   Original crossings: 23
#   Flipped indices: (9,)
#   Min crossings found: 11
#
# --- Knot variant 245/2288 ---
#   Original crossings: 23
#   Flipped indices: (10,)
#   Min crossings found: 11
#
# --- Knot variant 246/2288 ---
#   Original crossings: 23
#   Flipped indices: (11,)
#   Min crossings found: 11
#
# --- Knot variant 247/2288 ---
#   Original crossings: 23
#   Flipped indices: (12,)
#   Min crossings found: 11
#
# --- Knot variant 248/2288 ---
#   Original crossings: 23
#   Flipped indices: (13,)
#   Min crossings found: 15
#
# --- Knot variant 249/2288 ---
#   Original crossings: 23
#   Flipped indices: (14,)
#   Min crossings found: 11
#
# --- Knot variant 250/2288 ---
#   Original crossings: 23
#   Flipped indices: (15,)
#   Min crossings found: 11
#
# --- Knot variant 251/2288 ---
#   Original crossings: 23
#   Flipped indices: (16,)
#   Min crossings found: 15
#
# --- Knot variant 252/2288 ---
#   Original crossings: 23
#   Flipped indices: (17,)
#   Min crossings found: 13
#
# --- Knot variant 253/2288 ---
#   Original crossings: 23
#   Flipped indices: (18,)
#   Min crossings found: 15
#
# --- Knot variant 254/2288 ---
#   Original crossings: 23
#   Flipped indices: (19,)
#   Min crossings found: 11
#
# --- Knot variant 255/2288 ---
#   Original crossings: 23
#   Flipped indices: (20,)
#   Min crossings found: 9
#
# --- Knot variant 256/2288 ---
#   Original crossings: 23
#   Flipped indices: (21,)
#   Min crossings found: 15
#
# --- Knot variant 257/2288 ---
#   Original crossings: 23
#   Flipped indices: (22,)
#   Min crossings found: 13
#
# --- Knot variant 258/2288 ---
#   Original crossings: 21
#   Flipped indices: (0,)
#   Min crossings found: 9
#
# --- Knot variant 259/2288 ---
#   Original crossings: 21
#   Flipped indices: (1,)
#   Min crossings found: 9
#
# --- Knot variant 260/2288 ---
#   Original crossings: 21
#   Flipped indices: (2,)
#   Min crossings found: 9
#
# --- Knot variant 261/2288 ---
#   Original crossings: 21
#   Flipped indices: (3,)
#   Min crossings found: 9
#
# --- Knot variant 262/2288 ---
#   Original crossings: 21
#   Flipped indices: (4,)
#   Min crossings found: 11
#
# --- Knot variant 263/2288 ---
#   Original crossings: 21
#   Flipped indices: (5,)
#   Min crossings found: 11
#
# --- Knot variant 264/2288 ---
#   Original crossings: 21
#   Flipped indices: (6,)
#   Min crossings found: 11
#
# --- Knot variant 265/2288 ---
#   Original crossings: 21
#   Flipped indices: (7,)
#   Min crossings found: 11
#
# --- Knot variant 266/2288 ---
#   Original crossings: 21
#   Flipped indices: (8,)
#   Min crossings found: 11
#
# --- Knot variant 267/2288 ---
#   Original crossings: 21
#   Flipped indices: (9,)
#   Min crossings found: 11
#
# --- Knot variant 268/2288 ---
#   Original crossings: 21
#   Flipped indices: (10,)
#   Min crossings found: 11
#
# --- Knot variant 269/2288 ---
#   Original crossings: 21
#   Flipped indices: (11,)
#   Min crossings found: 11
#
# --- Knot variant 270/2288 ---
#   Original crossings: 21
#   Flipped indices: (12,)
#   Min crossings found: 11
#
# --- Knot variant 271/2288 ---
#   Original crossings: 21
#   Flipped indices: (13,)
#   Min crossings found: 13
#
# --- Knot variant 272/2288 ---
#   Original crossings: 21
#   Flipped indices: (14,)
#   Min crossings found: 15
#
# --- Knot variant 273/2288 ---
#   Original crossings: 21
#   Flipped indices: (15,)
#   Min crossings found: 11
#
# --- Knot variant 274/2288 ---
#   Original crossings: 21
#   Flipped indices: (16,)
#   Min crossings found: 15
#
# --- Knot variant 275/2288 ---
#   Original crossings: 21
#   Flipped indices: (17,)
#   Min crossings found: 13
#
# --- Knot variant 276/2288 ---
#   Original crossings: 21
#   Flipped indices: (18,)
#   Min crossings found: 13
#
# --- Knot variant 277/2288 ---
#   Original crossings: 21
#   Flipped indices: (19,)
#   Min crossings found: 13
#
# --- Knot variant 278/2288 ---
#   Original crossings: 21
#   Flipped indices: (20,)
#   Min crossings found: 13
#
# --- Knot variant 279/2288 ---
#   Original crossings: 22
#   Flipped indices: (0,)
#   Min crossings found: 9
#
# --- Knot variant 280/2288 ---
#   Original crossings: 22
#   Flipped indices: (1,)
#   Min crossings found: 9
#
# --- Knot variant 281/2288 ---
#   Original crossings: 22
#   Flipped indices: (2,)
#   Min crossings found: 9
#
# --- Knot variant 282/2288 ---
#   Original crossings: 22
#   Flipped indices: (3,)
#   Min crossings found: 9
#
# --- Knot variant 283/2288 ---
#   Original crossings: 22
#   Flipped indices: (4,)
#   Min crossings found: 11
#
# --- Knot variant 284/2288 ---
#   Original crossings: 22
#   Flipped indices: (5,)
#   Min crossings found: 11
#
# --- Knot variant 285/2288 ---
#   Original crossings: 22
#   Flipped indices: (6,)
#   Min crossings found: 11
#
# --- Knot variant 286/2288 ---
#   Original crossings: 22
#   Flipped indices: (7,)
#   Min crossings found: 11
#
# --- Knot variant 287/2288 ---
#   Original crossings: 22
#   Flipped indices: (8,)
#   Min crossings found: 11
#
# --- Knot variant 288/2288 ---
#   Original crossings: 22
#   Flipped indices: (9,)
#   Min crossings found: 11
#
# --- Knot variant 289/2288 ---
#   Original crossings: 22
#   Flipped indices: (10,)
#   Min crossings found: 11
#
# --- Knot variant 290/2288 ---
#   Original crossings: 22
#   Flipped indices: (11,)
#   Min crossings found: 11
#
# --- Knot variant 291/2288 ---
#   Original crossings: 22
#   Flipped indices: (12,)
#   Min crossings found: 11
#
# --- Knot variant 292/2288 ---
#   Original crossings: 22
#   Flipped indices: (13,)
#   Min crossings found: 13
#
# --- Knot variant 293/2288 ---
#   Original crossings: 22
#   Flipped indices: (14,)
#   Min crossings found: 11
#
# --- Knot variant 294/2288 ---
#   Original crossings: 22
#   Flipped indices: (15,)
#   Min crossings found: 15
#
# --- Knot variant 295/2288 ---
#   Original crossings: 22
#   Flipped indices: (16,)
#   Min crossings found: 13
#
# --- Knot variant 296/2288 ---
#   Original crossings: 22
#   Flipped indices: (17,)
#   Min crossings found: 15
#
# --- Knot variant 297/2288 ---
#   Original crossings: 22
#   Flipped indices: (18,)
#   Min crossings found: 11
#
# --- Knot variant 298/2288 ---
#   Original crossings: 22
#   Flipped indices: (19,)
#   Min crossings found: 11
#
# --- Knot variant 299/2288 ---
#   Original crossings: 22
#   Flipped indices: (20,)
#   Min crossings found: 15
#
# --- Knot variant 300/2288 ---
#   Original crossings: 22
#   Flipped indices: (21,)
#   Min crossings found: 13
#
# --- Knot variant 301/2288 ---
#   Original crossings: 23
#   Flipped indices: (0,)
#   Min crossings found: 9
#
# --- Knot variant 302/2288 ---
#   Original crossings: 23
#   Flipped indices: (1,)
#   Min crossings found: 9
#
# --- Knot variant 303/2288 ---
#   Original crossings: 23
#   Flipped indices: (2,)
#   Min crossings found: 9
#
# --- Knot variant 304/2288 ---
#   Original crossings: 23
#   Flipped indices: (3,)
#   Min crossings found: 9
#
# --- Knot variant 305/2288 ---
#   Original crossings: 23
#   Flipped indices: (4,)
#   Min crossings found: 11
#
# --- Knot variant 306/2288 ---
#   Original crossings: 23
#   Flipped indices: (5,)
#   Min crossings found: 11
#
# --- Knot variant 307/2288 ---
#   Original crossings: 23
#   Flipped indices: (6,)
#   Min crossings found: 11
#
# --- Knot variant 308/2288 ---
#   Original crossings: 23
#   Flipped indices: (7,)
#   Min crossings found: 11
#
# --- Knot variant 309/2288 ---
#   Original crossings: 23
#   Flipped indices: (8,)
#   Min crossings found: 11
#
# --- Knot variant 310/2288 ---
#   Original crossings: 23
#   Flipped indices: (9,)
#   Min crossings found: 11
#
# --- Knot variant 311/2288 ---
#   Original crossings: 23
#   Flipped indices: (10,)
#   Min crossings found: 11
#
# --- Knot variant 312/2288 ---
#   Original crossings: 23
#   Flipped indices: (11,)
#   Min crossings found: 11
#
# --- Knot variant 313/2288 ---
#   Original crossings: 23
#   Flipped indices: (12,)
#   Min crossings found: 11
#
# --- Knot variant 314/2288 ---
#   Original crossings: 23
#   Flipped indices: (13,)
#   Min crossings found: 13
#
# --- Knot variant 315/2288 ---
#   Original crossings: 23
#   Flipped indices: (14,)
#   Min crossings found: 15
#
# --- Knot variant 316/2288 ---
#   Original crossings: 23
#   Flipped indices: (15,)
#   Min crossings found: 9
#
# --- Knot variant 317/2288 ---
#   Original crossings: 23
#   Flipped indices: (16,)
#   Min crossings found: 13
#
# --- Knot variant 318/2288 ---
#   Original crossings: 23
#   Flipped indices: (17,)
#   Min crossings found: 9
#
# --- Knot variant 319/2288 ---
#   Original crossings: 23
#   Flipped indices: (18,)
#   Min crossings found: 15
#
# --- Knot variant 320/2288 ---
#   Original crossings: 23
#   Flipped indices: (19,)
#   Min crossings found: 9
#
# --- Knot variant 321/2288 ---
#   Original crossings: 23
#   Flipped indices: (20,)
#   Min crossings found: 15
#
# --- Knot variant 322/2288 ---
#   Original crossings: 23
#   Flipped indices: (21,)
#   Min crossings found: 15
#
# --- Knot variant 323/2288 ---
#   Original crossings: 23
#   Flipped indices: (22,)
#   Min crossings found: 15
#
# --- Knot variant 324/2288 ---
#   Original crossings: 23
#   Flipped indices: (0,)
#   Min crossings found: 9
#
# --- Knot variant 325/2288 ---
#   Original crossings: 23
#   Flipped indices: (1,)
#   Min crossings found: 9
#
# --- Knot variant 326/2288 ---
#   Original crossings: 23
#   Flipped indices: (2,)
#   Min crossings found: 9
#
# --- Knot variant 327/2288 ---
#   Original crossings: 23
#   Flipped indices: (3,)
#   Min crossings found: 9
#
# --- Knot variant 328/2288 ---
#   Original crossings: 23
#   Flipped indices: (4,)
#   Min crossings found: 11
#
# --- Knot variant 329/2288 ---
#   Original crossings: 23
#   Flipped indices: (5,)
#   Min crossings found: 11
#
# --- Knot variant 330/2288 ---
#   Original crossings: 23
#   Flipped indices: (6,)
#   Min crossings found: 11
#
# --- Knot variant 331/2288 ---
#   Original crossings: 23
#   Flipped indices: (7,)
#   Min crossings found: 11
#
# --- Knot variant 332/2288 ---
#   Original crossings: 23
#   Flipped indices: (8,)
#   Min crossings found: 11
#
# --- Knot variant 333/2288 ---
#   Original crossings: 23
#   Flipped indices: (9,)
#   Min crossings found: 11
#
# --- Knot variant 334/2288 ---
#   Original crossings: 23
#   Flipped indices: (10,)
#   Min crossings found: 11
#
# --- Knot variant 335/2288 ---
#   Original crossings: 23
#   Flipped indices: (11,)
#   Min crossings found: 11
#
# --- Knot variant 336/2288 ---
#   Original crossings: 23
#   Flipped indices: (12,)
#   Min crossings found: 11
#
# --- Knot variant 337/2288 ---
#   Original crossings: 23
#   Flipped indices: (13,)
#   Min crossings found: 13
#
# --- Knot variant 338/2288 ---
#   Original crossings: 23
#   Flipped indices: (14,)
#   Min crossings found: 15
#
# --- Knot variant 339/2288 ---
#   Original crossings: 23
#   Flipped indices: (15,)
#   Min crossings found: 9
#
# --- Knot variant 340/2288 ---
#   Original crossings: 23
#   Flipped indices: (16,)
#   Min crossings found: 15
#
# --- Knot variant 341/2288 ---
#   Original crossings: 23
#   Flipped indices: (17,)
#   Min crossings found: 9
#
# --- Knot variant 342/2288 ---
#   Original crossings: 23
#   Flipped indices: (18,)
#   Min crossings found: 16
#
# --- Knot variant 343/2288 ---
#   Original crossings: 23
#   Flipped indices: (19,)
#   Min crossings found: 15
#
# --- Knot variant 344/2288 ---
#   Original crossings: 23
#   Flipped indices: (20,)
#   Min crossings found: 13
#
# --- Knot variant 345/2288 ---
#   Original crossings: 23
#   Flipped indices: (21,)
#   Min crossings found: 13
#
# --- Knot variant 346/2288 ---
#   Original crossings: 23
#   Flipped indices: (22,)
#   Min crossings found: 13
#
# --- Knot variant 347/2288 ---
#   Original crossings: 25
#   Flipped indices: (0,)
#   Min crossings found: 9
#
# --- Knot variant 348/2288 ---
#   Original crossings: 25
#   Flipped indices: (1,)
#   Min crossings found: 9
#
# --- Knot variant 349/2288 ---
#   Original crossings: 25
#   Flipped indices: (2,)
#   Min crossings found: 9
#
# --- Knot variant 350/2288 ---
#   Original crossings: 25
#   Flipped indices: (3,)
#   Min crossings found: 9
#
# --- Knot variant 351/2288 ---
#   Original crossings: 25
#   Flipped indices: (4,)
#   Min crossings found: 11
#
# --- Knot variant 352/2288 ---
#   Original crossings: 25
#   Flipped indices: (5,)
#   Min crossings found: 11
#
# --- Knot variant 353/2288 ---
#   Original crossings: 25
#   Flipped indices: (6,)
#   Min crossings found: 11
#
# --- Knot variant 354/2288 ---
#   Original crossings: 25
#   Flipped indices: (7,)
#   Min crossings found: 11
#
# --- Knot variant 355/2288 ---
#   Original crossings: 25
#   Flipped indices: (8,)
#   Min crossings found: 11
#
# --- Knot variant 356/2288 ---
#   Original crossings: 25
#   Flipped indices: (9,)
#   Min crossings found: 11
#
# --- Knot variant 357/2288 ---
#   Original crossings: 25
#   Flipped indices: (10,)
#   Min crossings found: 11
#
# --- Knot variant 358/2288 ---
#   Original crossings: 25
#   Flipped indices: (11,)
#   Min crossings found: 11
#
# --- Knot variant 359/2288 ---
#   Original crossings: 25
#   Flipped indices: (12,)
#   Min crossings found: 11
#
# --- Knot variant 360/2288 ---
#   Original crossings: 25
#   Flipped indices: (13,)
#   Min crossings found: 11
#
# --- Knot variant 361/2288 ---
#   Original crossings: 25
#   Flipped indices: (14,)
#   Min crossings found: 15
#
# --- Knot variant 362/2288 ---
#   Original crossings: 25
#   Flipped indices: (15,)
#   Min crossings found: 15
#
# --- Knot variant 363/2288 ---
#   Original crossings: 25
#   Flipped indices: (16,)
#   Min crossings found: 11
#
# --- Knot variant 364/2288 ---
#   Original crossings: 25
#   Flipped indices: (17,)
#   Min crossings found: 11
#
# --- Knot variant 365/2288 ---
#   Original crossings: 25
#   Flipped indices: (18,)
#   Min crossings found: 15
#
# --- Knot variant 366/2288 ---
#   Original crossings: 25
#   Flipped indices: (19,)
#   Min crossings found: 9
#
# --- Knot variant 367/2288 ---
#   Original crossings: 25
#   Flipped indices: (20,)
#   Min crossings found: 15
#
# --- Knot variant 368/2288 ---
#   Original crossings: 25
#   Flipped indices: (21,)
#   Min crossings found: 15
#
# --- Knot variant 369/2288 ---
#   Original crossings: 25
#   Flipped indices: (22,)
#   Min crossings found: 11
#
# --- Knot variant 370/2288 ---
#   Original crossings: 25
#   Flipped indices: (23,)
#   Min crossings found: 11
#
# --- Knot variant 371/2288 ---
#   Original crossings: 25
#   Flipped indices: (24,)
#   Min crossings found: 15
#
# --- Knot variant 372/2288 ---
#   Original crossings: 22
#   Flipped indices: (0,)
#   Min crossings found: 9
#
# --- Knot variant 373/2288 ---
#   Original crossings: 22
#   Flipped indices: (1,)
#   Min crossings found: 9
#
# --- Knot variant 374/2288 ---
#   Original crossings: 22
#   Flipped indices: (2,)
#   Min crossings found: 9
#
# --- Knot variant 375/2288 ---
#   Original crossings: 22
#   Flipped indices: (3,)
#   Min crossings found: 9
#
# --- Knot variant 376/2288 ---
#   Original crossings: 22
#   Flipped indices: (4,)
#   Min crossings found: 11
#
# --- Knot variant 377/2288 ---
#   Original crossings: 22
#   Flipped indices: (5,)
#   Min crossings found: 11
#
# --- Knot variant 378/2288 ---
#   Original crossings: 22
#   Flipped indices: (6,)
#   Min crossings found: 11
#
# --- Knot variant 379/2288 ---
#   Original crossings: 22
#   Flipped indices: (7,)
#   Min crossings found: 11
#
# --- Knot variant 380/2288 ---
#   Original crossings: 22
#   Flipped indices: (8,)
#   Min crossings found: 11
#
# --- Knot variant 381/2288 ---
#   Original crossings: 22
#   Flipped indices: (9,)
#   Min crossings found: 11
#
# --- Knot variant 382/2288 ---
#   Original crossings: 22
#   Flipped indices: (10,)
#   Min crossings found: 11
#
# --- Knot variant 383/2288 ---
#   Original crossings: 22
#   Flipped indices: (11,)
#   Min crossings found: 11
#
# --- Knot variant 384/2288 ---
#   Original crossings: 22
#   Flipped indices: (12,)
#   Min crossings found: 11
#
# --- Knot variant 385/2288 ---
#   Original crossings: 22
#   Flipped indices: (13,)
#   Min crossings found: 13
#
# --- Knot variant 386/2288 ---
#   Original crossings: 22
#   Flipped indices: (14,)
#   Min crossings found: 13
#
# --- Knot variant 387/2288 ---
#   Original crossings: 22
#   Flipped indices: (15,)
#   Min crossings found: 9
#
# --- Knot variant 388/2288 ---
#   Original crossings: 22
#   Flipped indices: (16,)
#   Min crossings found: 15
#
# --- Knot variant 389/2288 ---
#   Original crossings: 22
#   Flipped indices: (17,)
#   Min crossings found: 15
#
# --- Knot variant 390/2288 ---
#   Original crossings: 22
#   Flipped indices: (18,)
#   Min crossings found: 9
#
# --- Knot variant 391/2288 ---
#   Original crossings: 22
#   Flipped indices: (19,)
#   Min crossings found: 13
#
# --- Knot variant 392/2288 ---
#   Original crossings: 22
#   Flipped indices: (20,)
#   Min crossings found: 15
#
# --- Knot variant 393/2288 ---
#   Original crossings: 22
#   Flipped indices: (21,)
#   Min crossings found: 9
#
# --- Knot variant 394/2288 ---
#   Original crossings: 23
#   Flipped indices: (0,)
#   Min crossings found: 9
#
# --- Knot variant 395/2288 ---
#   Original crossings: 23
#   Flipped indices: (1,)
#   Min crossings found: 9
#
# --- Knot variant 396/2288 ---
#   Original crossings: 23
#   Flipped indices: (2,)
#   Min crossings found: 9
#
# --- Knot variant 397/2288 ---
#   Original crossings: 23
#   Flipped indices: (3,)
#   Min crossings found: 9
#
# --- Knot variant 398/2288 ---
#   Original crossings: 23
#   Flipped indices: (4,)
#   Min crossings found: 11
#
# --- Knot variant 399/2288 ---
#   Original crossings: 23
#   Flipped indices: (5,)
#   Min crossings found: 11
#
# --- Knot variant 400/2288 ---
#   Original crossings: 23
#   Flipped indices: (6,)
#   Min crossings found: 11
#
# --- Knot variant 401/2288 ---
#   Original crossings: 23
#   Flipped indices: (7,)
#   Min crossings found: 11
#
# --- Knot variant 402/2288 ---
#   Original crossings: 23
#   Flipped indices: (8,)
#   Min crossings found: 11
#
# --- Knot variant 403/2288 ---
#   Original crossings: 23
#   Flipped indices: (9,)
#   Min crossings found: 11
#
# --- Knot variant 404/2288 ---
#   Original crossings: 23
#   Flipped indices: (10,)
#   Min crossings found: 11
#
# --- Knot variant 405/2288 ---
#   Original crossings: 23
#   Flipped indices: (11,)
#   Min crossings found: 11
#
# --- Knot variant 406/2288 ---
#   Original crossings: 23
#   Flipped indices: (12,)
#   Min crossings found: 11
#
# --- Knot variant 407/2288 ---
#   Original crossings: 23
#   Flipped indices: (13,)
#   Min crossings found: 11
#
# --- Knot variant 408/2288 ---
#   Original crossings: 23
#   Flipped indices: (14,)
#   Min crossings found: 15
#
# --- Knot variant 409/2288 ---
#   Original crossings: 23
#   Flipped indices: (15,)
#   Min crossings found: 15
#
# --- Knot variant 410/2288 ---
#   Original crossings: 23
#   Flipped indices: (16,)
#   Min crossings found: 9
#
# --- Knot variant 411/2288 ---
#   Original crossings: 23
#   Flipped indices: (17,)
#   Min crossings found: 13
#
# --- Knot variant 412/2288 ---
#   Original crossings: 23
#   Flipped indices: (18,)
#   Min crossings found: 15
#
# --- Knot variant 413/2288 ---
#   Original crossings: 23
#   Flipped indices: (19,)
#   Min crossings found: 11
#
# --- Knot variant 414/2288 ---
#   Original crossings: 23
#   Flipped indices: (20,)
#   Min crossings found: 13
#
# --- Knot variant 415/2288 ---
#   Original crossings: 23
#   Flipped indices: (21,)
#   Min crossings found: 15
#
# --- Knot variant 416/2288 ---
#   Original crossings: 23
#   Flipped indices: (22,)
#   Min crossings found: 11
#
# --- Knot variant 417/2288 ---
#   Original crossings: 21
#   Flipped indices: (0,)
#   Min crossings found: 9
#
# --- Knot variant 418/2288 ---
#   Original crossings: 21
#   Flipped indices: (1,)
#   Min crossings found: 9
#
# --- Knot variant 419/2288 ---
#   Original crossings: 21
#   Flipped indices: (2,)
#   Min crossings found: 9
#
# --- Knot variant 420/2288 ---
#   Original crossings: 21
#   Flipped indices: (3,)
#   Min crossings found: 9
#
# --- Knot variant 421/2288 ---
#   Original crossings: 21
#   Flipped indices: (4,)
#   Min crossings found: 11
#
# --- Knot variant 422/2288 ---
#   Original crossings: 21
#   Flipped indices: (5,)
#   Min crossings found: 11
#
# --- Knot variant 423/2288 ---
#   Original crossings: 21
#   Flipped indices: (6,)
#   Min crossings found: 11
#
# --- Knot variant 424/2288 ---
#   Original crossings: 21
#   Flipped indices: (7,)
#   Min crossings found: 11
#
# --- Knot variant 425/2288 ---
#   Original crossings: 21
#   Flipped indices: (8,)
#   Min crossings found: 11
#
# --- Knot variant 426/2288 ---
#   Original crossings: 21
#   Flipped indices: (9,)
#   Min crossings found: 11
#
# --- Knot variant 427/2288 ---
#   Original crossings: 21
#   Flipped indices: (10,)
#   Min crossings found: 11
#
# --- Knot variant 428/2288 ---
#   Original crossings: 21
#   Flipped indices: (11,)
#   Min crossings found: 11
#
# --- Knot variant 429/2288 ---
#   Original crossings: 21
#   Flipped indices: (12,)
#   Min crossings found: 11
#
# --- Knot variant 430/2288 ---
#   Original crossings: 21
#   Flipped indices: (13,)
#   Min crossings found: 15
#
# --- Knot variant 431/2288 ---
#   Original crossings: 21
#   Flipped indices: (14,)
#   Min crossings found: 11
#
# --- Knot variant 432/2288 ---
#   Original crossings: 21
#   Flipped indices: (15,)
#   Min crossings found: 13
#
# --- Knot variant 433/2288 ---
#   Original crossings: 21
#   Flipped indices: (16,)
#   Min crossings found: 11
#
# --- Knot variant 434/2288 ---
#   Original crossings: 21
#   Flipped indices: (17,)
#   Min crossings found: 15
#
# --- Knot variant 435/2288 ---
#   Original crossings: 21
#   Flipped indices: (18,)
#   Min crossings found: 13
#
# --- Knot variant 436/2288 ---
#   Original crossings: 21
#   Flipped indices: (19,)
#   Min crossings found: 13
#
# --- Knot variant 437/2288 ---
#   Original crossings: 21
#   Flipped indices: (20,)
#   Min crossings found: 13
#
# --- Knot variant 438/2288 ---
#   Original crossings: 22
#   Flipped indices: (0,)
#   Min crossings found: 9
#
# --- Knot variant 439/2288 ---
#   Original crossings: 22
#   Flipped indices: (1,)
#   Min crossings found: 9
#
# --- Knot variant 440/2288 ---
#   Original crossings: 22
#   Flipped indices: (2,)
#   Min crossings found: 9
#
# --- Knot variant 441/2288 ---
#   Original crossings: 22
#   Flipped indices: (3,)
#   Min crossings found: 9
#
# --- Knot variant 442/2288 ---
#   Original crossings: 22
#   Flipped indices: (4,)
#   Min crossings found: 11
#
# --- Knot variant 443/2288 ---
#   Original crossings: 22
#   Flipped indices: (5,)
#   Min crossings found: 11
#
# --- Knot variant 444/2288 ---
#   Original crossings: 22
#   Flipped indices: (6,)
#   Min crossings found: 11
#
# --- Knot variant 445/2288 ---
#   Original crossings: 22
#   Flipped indices: (7,)
#   Min crossings found: 11
#
# --- Knot variant 446/2288 ---
#   Original crossings: 22
#   Flipped indices: (8,)
#   Min crossings found: 11
#
# --- Knot variant 447/2288 ---
#   Original crossings: 22
#   Flipped indices: (9,)
#   Min crossings found: 11
#
# --- Knot variant 448/2288 ---
#   Original crossings: 22
#   Flipped indices: (10,)
#   Min crossings found: 11
#
# --- Knot variant 449/2288 ---
#   Original crossings: 22
#   Flipped indices: (11,)
#   Min crossings found: 11
#
# --- Knot variant 450/2288 ---
#   Original crossings: 22
#   Flipped indices: (12,)
#   Min crossings found: 11
#
# --- Knot variant 451/2288 ---
#   Original crossings: 22
#   Flipped indices: (13,)
#   Min crossings found: 13
#
# ...
# Knot 2138: Original Crossings=23, Flipped Indices=(10,), RL Unknot Success=False, Min Crossings Found=11
# Knot 2139: Original Crossings=23, Flipped Indices=(11,), RL Unknot Success=False, Min Crossings Found=11
# Knot 2140: Original Crossings=23, Flipped Indices=(12,), RL Unknot Success=False, Min Crossings Found=11
# Knot 2141: Original Crossings=23, Flipped Indices=(13,), RL Unknot Success=False, Min Crossings Found=13
# Knot 2142: Original Crossings=23, Flipped Indices=(14,), RL Unknot Success=False, Min Crossings Found=15
# Knot 2143: Original Crossings=23, Flipped Indices=(15,), RL Unknot Success=False, Min Crossings Found=9
# Knot 2144: Original Crossings=23, Flipped Indices=(16,), RL Unknot Success=False, Min Crossings Found=15
# Knot 2145: Original Crossings=23, Flipped Indices=(17,), RL Unknot Success=False, Min Crossings Found=9
# Knot 2146: Original Crossings=23, Flipped Indices=(18,), RL Unknot Success=False, Min Crossings Found=15
# Knot 2147: Original Crossings=23, Flipped Indices=(19,), RL Unknot Success=False, Min Crossings Found=11
# Knot 
), RL Unknot Success=False, Min Crossings Found=11
# Knot 2274: Original Crossings=23, Flipped Indices=(8,), RL Unknot Success=False, Min Crossings Found=11
# Knot 2275: Original Crossings=23, Flipped Indices=(9,), RL Unknot Success=False, Min Crossings Found=11
# Knot 2276: Original Crossings=23, Flipped Indices=(10,), RL Unknot Success=False, Min Crossings Found=11
# Knot 2277: Original Crossings=23, Flipped Indices=(11,), RL Unknot Success=False, Min Crossings Found=11
# Knot 2278: Original Crossings=23, Flipped Indices=(12,), RL Unknot Success=False, Min Crossings Found=11
# Knot 2279: Original Crossings=23, Flipped Indices=(13,), RL Unknot Success=False, Min Crossings Found=13
# Knot 2280: Original Crossings=23, Flipped Indices=(14,), RL Unknot Success=False, Min Crossings Found=13
# Knot 2281: Original Crossings=23, Flipped Indices=(15,), RL Unknot Success=False, Min Crossings Found=13
# Knot 2282: Original Crossings=23, Flipped Indices=(16,), RL Unknot Success=False, Min Crossings Found=13
# Knot 2283: Original Crossings=23, Flipped Indices=(17,), RL Unknot Success=False, Min Crossings Found=11
# Knot 2284: Original Crossings=23, Flipped Indices=(18,), RL Unknot Success=False, Min Crossings Found=15
# Knot 2285: Original Crossings=23, Flipped Indices=(19,), RL Unknot Success=False, Min Crossings Found=13
# Knot 2286: Original Crossings=23, Flipped Indices=(20,), RL Unknot Success=False, Min Crossings Found=13
# Knot 2287: Original Crossings=23, Flipped Indices=(21,), RL Unknot Success=False, Min Crossings Found=15
# Knot 2288: Original Crossings=23, Flipped Indices=(22,), RL Unknot Success=False, Min Crossings Found=15
# ========================================================================
#
# Wrote minimal-PD results to: /home/dani/uncrossing-number/notebooks/data/min_pd_results_flips1.jsonl

# %%
# ============================================================
# Compute Jones polynomial from RL-minimal PDs (pure python)
# Writes: OUT_DIR/min_pd_results_flips{flips}_jones.jsonl
# Defines: results (list of dicts), for downstream cells
# ============================================================

import os, json
from fractions import Fraction

# --- require OUT_DIR + flips (as in your notebook conventions) ---
if "OUT_DIR" not in globals():
    raise NameError("OUT_DIR is not defined. Run your Drive/paths cell first.")
if "flips" not in globals():
    raise NameError("flips is not defined. Run the 'import itertools' cell first.")

in_path = os.path.join(OUT_DIR, f"min_pd_results_flips{flips}.jsonl")
if not os.path.exists(in_path):
    raise FileNotFoundError(f"Missing input JSONL: {in_path}. Run the 'import itertools' cell first.")

# -------------------------
# Laurent polynomial in A: dict exponent(int) -> coeff(int)
# -------------------------
def poly_add(p, q):
    r = dict(p)
    for e, c in q.items():
        r[e] = r.get(e, 0) + c
        if r[e] == 0:
            del r[e]
    return r

def poly_mul(p, q):
    r = {}
    for e1, c1 in p.items():
        for e2, c2 in q.items():
            e = e1 + e2
            r[e] = r.get(e, 0) + c1 * c2
    return {e:c for e,c in r.items() if c != 0}

def poly_monom(e, c=1):
    return {e: c} if c != 0 else {}

def poly_scale(p, k):
    if k == 0:
        return {}
    return {e: c*k for e,c in p.items()}

# -------------------------
# Union-Find for loop counting in each state
# -------------------------
class DSU:
    def __init__(self):
        self.parent = {}
        self.rank = {}
    def find(self, x):
        if x not in self.parent:
            self.parent[x] = x
            self.rank[x] = 0
            return x
        while self.parent[x] != x:
            self.parent[x] = self.parent[self.parent[x]]
            x = self.parent[x]
        return x
    def union(self, a, b):
        ra, rb = self.find(a), self.find(b)
        if ra == rb:
            return
        if self.rank[ra] < self.rank[rb]:
            ra, rb = rb, ra
        self.parent[rb] = ra
        if self.rank[ra] == self.rank[rb]:
            self.rank[ra] += 1
    def n_components(self):
        roots = set(self.find(x) for x in self.parent.keys())
        return len(roots)

# -------------------------
# Kauffman bracket from PD
# Convention:
#   A-smoothing pairs (a,b) and (c,d)
#   B-smoothing pairs (b,c) and (d,a)
# -------------------------
def bracket_from_pd(pd):
    n = len(pd)
    # Delta = -A^2 - A^-2
    Delta = poly_add(poly_scale(poly_monom(2), -1), poly_scale(poly_monom(-2), -1))

    labels = set()
    for (a,b,c,d) in pd:
        labels.update([a,b,c,d])

    total = {}

    for mask in range(1 << n):
        dsu = DSU()
        for x in labels:
            dsu.find(x)

        a_count = 0
        b_count = 0

        for i, (a,b,c,d) in enumerate(pd):
            if ((mask >> i) & 1) == 0:
                a_count += 1
                dsu.union(a, b)
                dsu.union(c, d)
            else:
                b_count += 1
                dsu.union(b, c)
                dsu.union(d, a)

        loops = dsu.n_components()
        mon = poly_monom(a_count - b_count, 1)

        # Delta^(loops-1)
        factor = {0: 1}
        for _ in range(loops - 1):
            factor = poly_mul(factor, Delta)

        total = poly_add(total, poly_mul(mon, factor))

    return total

# -------------------------
# Writhe heuristic (only affects an overall monomial shift)
# You told me you don't care about shift; still, keep it consistent.
# -------------------------
def crossing_sign_pd(quad):
    a,b,c,d = quad
    return 1 if (a < c) == (b < d) else -1

# -------------------------
# Convert bracket(A) to a Jones-like polynomial in variable t with integer exponents
# Using the usual normalization V = (-A)^(-3w) <D>, then substitute A = t^(-1/4).
# In typical PD conventions from the same generator, exponents land in Z.
# -------------------------
def jones_string_from_pd(pd_list):
    if not pd_list:
        return None, "Empty PD"

    pd = [tuple(map(int, q)) for q in pd_list]

    try:
        br = bracket_from_pd(pd)
        w = sum(crossing_sign_pd(q) for q in pd)

        # multiply by (-A)^(-3w) = (-1)^(-3w) * A^(-3w)
        sign = -1 if ((-3*w) % 2) else 1
        norm = poly_scale(poly_monom(-3*w, 1), sign)
        normed = poly_mul(norm, br)

        # Substitute A = t^(-1/4): A^e -> t^(-e/4)
        jt = {}
        for eA, c in normed.items():
            eT = Fraction(-eA, 4)
            jt[eT] = jt.get(eT, 0) + c
        jt = {e:c for e,c in jt.items() if c != 0}

        # If exponents are not integers, we still print them (rare in your pipeline)
        def exp_to_str(fr):
            if fr == 0:
                return ""
            if fr.denominator == 1:
                k = fr.numerator
                if k == 1:
                    return "t"
                return f"t^{k}"
            return f"t^({fr.numerator}/{fr.denominator})"

        # build string with descending exponent
        terms = []
        for e in sorted(jt.keys(), reverse=True):
            c = jt[e]
            mon = exp_to_str(e)
            if mon == "":
                term = f"{c}"
            else:
                if c == 1:
                    term = mon
                elif c == -1:
                    term = "-" + mon
                else:
                    term = f"{c}*{mon}"
            terms.append(term)

        if not terms:
            return "0", None

        s = terms[0]
        for t in terms[1:]:
            if t.startswith("-"):
                s += " - " + t[1:]
            else:
                s += " + " + t

        return s, None

    except Exception as e:
        return None, repr(e)

# -------------------------
# Load RL-minimal PDs, compute Jones, write deterministic JSONL
# -------------------------
results = []
with open(in_path, "r") as f:
    for line in f:
        rec = json.loads(line)
        best_pd = rec.get("best_pd_list")
        jstr, jerr = jones_string_from_pd(best_pd)

        results.append({
            "knot_index": rec.get("knot_index"),
            "flipped_indices": rec.get("flipped_indices"),
            "rl_unknot_success": rec.get("rl_unknot_success"),
            "min_crossings_found": rec.get("min_crossings_found"),
            "best_pd_crossings": len(best_pd) if best_pd else None,
            "jones": jstr,
            "jones_error": jerr,
        })

out_jones = os.path.join(OUT_DIR, f"min_pd_results_flips{flips}_jones.jsonl")
with open(out_jones, "w") as f:
    for r in results:
        f.write(json.dumps(r) + "\n")

print(f"Loaded {len(results)} PDs from: {in_path}")
print(f"Wrote Jones results to:        {out_jones}")

# quick preview
for r in results[:5]:
    print(f"variant {r['knot_index']}: flips={r['flipped_indices']} bestX={r['best_pd_crossings']}  Jones={r['jones']}")

# %%
# ============================================================
# Patch: output KnotInfo-compatible Jones vectors
# Format: [min_exp, max_exp, c_min, c_{min+1}, ..., c_max]
# where exponents are for the Jones polynomial variable (whatever you're using),
# and coefficients include internal zeros.
#
# Works from your existing `results` list where each item has:
#   - "jones" as a string like "-t^-1 + t^-2 - 3*t^-3 + ..."
#   - plus metadata (knot_index, flipped_indices, best_pd_crossings, ...)
#
# Produces:
#   - vectors_ki: list of records with "jones_vec_knotinfo"
#   - writes JSONL + TXT (one vector per line) next to out_path
# ============================================================

import re, json, os, glob

# Fallback OUT_DIR if the Drive-paths cell hasn't run yet
if "OUT_DIR" not in globals():
    OUT_DIR = "/content"  # safe local fallback
    # If running on Colab and Drive is mounted, prefer your project folder
    drive_proj = "/content/drive/MyDrive/crossing-reduction-unknotting"
    if os.path.exists("/content/drive") and os.path.isdir(drive_proj):
        OUT_DIR = drive_proj
    print("OUT_DIR was not defined yet; using:", OUT_DIR)

# If `results` isn't defined in-memory, reconstruct it from a saved Jones JSONL
if "results" not in globals():
    # Try the deterministic name first if flips exists
    candidates = []
    if "flips" in globals():
        candidates.append(os.path.join(OUT_DIR, f"min_pd_results_flips{flips}_jones.jsonl"))

    # Otherwise, search for any Jones JSONL in OUT_DIR
    candidates += sorted(glob.glob(os.path.join(OUT_DIR, "min_pd_results_flips*_jones.jsonl")))

    if not candidates:
        raise FileNotFoundError(
            "Could not find any '*_jones.jsonl' file to load results from.\n"
            f"Searched in: {OUT_DIR}\n"
            "Run the Jones computation cell first (the one that writes *_jones.jsonl), "
            "or set OUT_DIR to the folder containing that file."
        )

    jones_jsonl = candidates[-1]  # pick the last one (usually latest / highest flips)
    results = []
    with open(jones_jsonl, "r") as f:
        for line in f:
            results.append(json.loads(line))
    print(f"Loaded results from {jones_jsonl} ({len(results)} records)")

_int_pat = re.compile(r"-?\d+")

def parse_jones_string_to_dict(jstr):
    """
    Parse: "-t^-1 + t^-2 - 3*t^-3 + 5*t^-4 ..." -> {exp:int coeff}
    Exponents must be integers.
    """
    if jstr is None:
        return None
    s = str(jstr).strip()
    if s == "" or s == "0":
        return {}

    s = s.replace(" - ", " + -")
    parts = [p.strip() for p in s.split(" + ") if p.strip()]

    poly = {}
    for term in parts:
        term = term.replace(" ", "")
        if term == "":
            continue

        # coefficient and monomial split
        if "*t" in term:
            c_str, mon = term.split("*", 1)
            coeff = int(c_str)
        elif term.startswith("t") or term.startswith("-t"):
            coeff = -1 if term.startswith("-t") else 1
            mon = term[1:] if term.startswith("-t") else term
        else:
            # constant
            coeff = int(term)
            exp = 0
            poly[exp] = poly.get(exp, 0) + coeff
            continue

        # parse exponent from mon (starts with 't')
        if mon == "t":
            exp = 1
        elif mon.startswith("t^"):
            exp = int(mon[2:])  # handles negative too
        else:
            raise ValueError(f"Unrecognized monomial format: {mon} (from term {term})")

        poly[exp] = poly.get(exp, 0) + coeff

    return {e: c for e, c in poly.items() if c != 0}

def poly_dict_to_knotinfo_vector(poly):
    """
    Convert dict exp->coeff to KnotInfo vector [min_exp, max_exp, coeffs...]
    filling internal zeros. If poly is empty -> [0,0,0].
    """
    if poly is None:
        return None
    if len(poly) == 0:
        return [0, 0, 0]

    min_exp = min(poly.keys())
    max_exp = max(poly.keys())
    coeffs = []
    for e in range(min_exp, max_exp + 1):
        coeffs.append(int(poly.get(e, 0)))
    return [int(min_exp), int(max_exp)] + coeffs

# Build KnotInfo-compatible vectors for every result
vectors_ki = []
for r in results:
    jstr = r.get("jones")
    try:
        poly = parse_jones_string_to_dict(jstr) if jstr is not None else None
        vec_ki = poly_dict_to_knotinfo_vector(poly) if poly is not None else None
        err = None
    except Exception as e:
        vec_ki = None
        err = repr(e)

    vectors_ki.append({
        "knot_index": r.get("knot_index"),
        "flipped_indices": r.get("flipped_indices"),
        "best_pd_crossings": r.get("best_pd_crossings"),
        "jones_vec_knotinfo": vec_ki,
        "jones_vec_error": err or r.get("jones_error"),
    })

# Print a compact preview
print("=== KnotInfo-compatible Jones vectors ===")
for v in vectors_ki:
    print(f"variant {v['knot_index']:>3} flips={v['flipped_indices']} bestX={v['best_pd_crossings']}  vec={v['jones_vec_knotinfo']}")

# Save (1) JSONL with metadata
out_path_ki_jsonl = out_path.replace(".jsonl", "_jones_vec_knotinfo.jsonl")
with open(out_path_ki_jsonl, "w") as f:
    for v in vectors_ki:
        f.write(json.dumps(v) + "\n")
print("\nWrote KnotInfo-compatible vectors (JSONL) to:", out_path_ki_jsonl)

# Save (2) TXT with just the vector per line (easy to grep / load)
out_path_ki_txt = out_path.replace(".jsonl", "_jones_vec_knotinfo.txt")
with open(out_path_ki_txt, "w") as f:
    for v in vectors_ki:
        f.write(str(v["jones_vec_knotinfo"]) + "\n")
print("Wrote KnotInfo-compatible vectors (TXT) to:", out_path_ki_txt)

# %%
# ============================================================
# FINAL: Match Jones vectors against KnotInfo (Run-all safe)
#   - Accepts only vectors of format [min,max,c0,...,cN] (always!)
#   - Matches up to:
#       * q-shift (ignored by comparing coeffs only)
#       * mirror (reverse coeffs)
#     with extra constraint:
#       * abs(min-max) must match between input and KnotInfo
# ============================================================

import os, re, json, ast, glob
import pandas as pd
from collections import defaultdict

# ----------------------------
# Ensure PROJECT_DIR / OUT_DIR exist (self-contained)
# ----------------------------
if "PROJECT_DIR" not in globals() or "OUT_DIR" not in globals():
    try:
        from google.colab import drive
        drive.mount("/content/drive")
    except Exception as e:
        raise RuntimeError(
            "Could not mount Google Drive automatically. "
            "If you're not in Colab, set PROJECT_DIR/OUT_DIR manually.\n"
            f"Error: {e!r}"
        )

    PROJECT_DIR = "/content/drive/MyDrive/crossing-reduction-unknotting"
    os.makedirs(PROJECT_DIR, exist_ok=True)
    OUT_DIR = PROJECT_DIR
    print("Initialized PROJECT_DIR =", PROJECT_DIR)
    print("Initialized OUT_DIR     =", OUT_DIR)

# ----------------------------
# Paths (Drive only, deterministic)
# ----------------------------
KNOTINFO_XLS_PATH = os.path.join(PROJECT_DIR, "knotinfo_data_complete.xls")
if not os.path.exists(KNOTINFO_XLS_PATH):
    raise FileNotFoundError(
        f"Missing KnotInfo file at:\n  {KNOTINFO_XLS_PATH}\n"
        "Please put 'knotinfo_data_complete.xls' into your Drive folder:\n"
        f"  {PROJECT_DIR}"
    )

# Auto-pick the newest/last vectors file in OUT_DIR
cands = sorted(glob.glob(os.path.join(OUT_DIR, "min_pd_results_flips*_jones_vec_knotinfo.txt")))
if not cands:
    raise FileNotFoundError(
        "Could not find any '*_jones_vec_knotinfo.txt' in OUT_DIR.\n"
        f"OUT_DIR = {OUT_DIR}\n"
        "Run the cell that writes KnotInfo-compatible Jones vectors first."
    )
USER_VECTORS_PATH = cands[-1]

print("KNOTINFO_XLS_PATH =", KNOTINFO_XLS_PATH)
print("USER_VECTORS_PATH =", USER_VECTORS_PATH)

# ----------------------------
# Read KnotInfo .xls (install xlrd if needed)
# ----------------------------
try:
    df = pd.read_excel(KNOTINFO_XLS_PATH)
except Exception:
    import sys, subprocess
    subprocess.check_call([sys.executable, "-m", "pip", "install", "-q", "xlrd"])
    df = pd.read_excel(KNOTINFO_XLS_PATH)

cols = list(df.columns)

def pick_col_contains_all(tokens):
    toks = [t.lower() for t in tokens]
    for c in cols:
        cl = c.lower()
        if all(t in cl for t in toks):
            return c
    return None

# knot name column
knot_col = None
for c in cols:
    if c.lower() in {"knot", "name", "knot_name", "knotname", "id"}:
        knot_col = c
        break
if knot_col is None:
    knot_col = cols[0]

# unknotting number column
u_col = None
for pat in (["unknotting", "number"], ["unknotting"], ["unknotting_number"], ["u("]):
    u_col = pick_col_contains_all(pat)
    if u_col:
        break

# Jones vector columns
jones_cols = [c for c in cols if ("jones" in c.lower() and ("vector" in c.lower() or "coeff" in c.lower() or "coefficient" in c.lower()))]
if not jones_cols:
    jones_cols = [c for c in cols if "jones" in c.lower()]
if not jones_cols:
    raise RuntimeError("Could not find any Jones-related column in KnotInfo XLS.")

print("Using knot column:", knot_col)
print("Using unknotting number column:", u_col)
print("Candidate Jones columns:", jones_cols[:8], ("(+%d more)" % (len(jones_cols)-8) if len(jones_cols) > 8 else ""))

_int_pat = re.compile(r"-?\d+")

def parse_vector_cell(x):
    if x is None or (isinstance(x, float) and pd.isna(x)):
        return None
    if isinstance(x, (list, tuple)):
        try:
            return [int(v) for v in x]
        except Exception:
            return None
    s = str(x).strip()
    if not s or s.lower() in {"nan", "none"}:
        return None
    if s.startswith("[") and s.endswith("]"):
        try:
            v = ast.literal_eval(s)
            if isinstance(v, (list, tuple)):
                return [int(z) for z in v]
        except Exception:
            pass
    nums = _int_pat.findall(s)
    if not nums:
        return None
    return [int(z) for z in nums]

def ensure_minmax_coeffs(v):
    """Require [min,max,coeffs...] with length == abs(max-min)+1."""
    if v is None:
        return None
    v = [int(x) for x in v]
    if len(v) < 3:
        return None
    mn, mx = v[0], v[1]
    coeffs = v[2:]
    span = abs(mx - mn)
    if len(coeffs) != span + 1:
        return None
    return mn, mx, coeffs

def strip_leading_trailing_zeros(coeffs):
    coeffs = list(map(int, coeffs))
    i, j = 0, len(coeffs)
    while i < j and coeffs[i] == 0:
        i += 1
    while j > i and coeffs[j-1] == 0:
        j -= 1
    out = coeffs[i:j]
    return out if out else [0]

def canon_coeff_key(coeffs):
    return tuple(strip_leading_trailing_zeros(coeffs))

def canon_coeff_key_mirror(coeffs):
    return tuple(reversed(strip_leading_trailing_zeros(coeffs)))

def span_abs(mn, mx):
    return abs(int(mx) - int(mn))

# ----------------------------
# Build lookup: (abs-span, coeff-key) -> candidates
# ----------------------------
lookup = defaultdict(list)
n_added = 0

for _, row in df.iterrows():
    knot_name = row.get(knot_col)
    u_val = row.get(u_col) if u_col is not None else None

    for jc in jones_cols:
        raw = parse_vector_cell(row.get(jc))
        parsed = ensure_minmax_coeffs(raw)
        if parsed is None:
            continue
        mn, mx, coeffs = parsed
        sp = span_abs(mn, mx)

        k = canon_coeff_key(coeffs)
        km = canon_coeff_key_mirror(coeffs)

        rec = {
            "knot": str(knot_name),
            "unknotting_number": None if (u_val is None or (isinstance(u_val, float) and pd.isna(u_val))) else u_val,
            "knotinfo_min": mn,
            "knotinfo_max": mx,
            "source_col": jc,
        }
        lookup[(sp, k)].append({**rec, "mirror": False})
        lookup[(sp, km)].append({**rec, "mirror": True})
        n_added += 1

print("Built lookup entries:", n_added)

# ----------------------------
# Load user vectors: REQUIRED format [min,max,c0,...]
# ----------------------------
user_vecs = []
with open(USER_VECTORS_PATH, "r") as f:
    for line in f:
        line = line.strip()
        if not line:
            continue
        try:
            v = ast.literal_eval(line)
        except Exception:
            v = parse_vector_cell(line)
        user_vecs.append(v)

print("Loaded user vectors:", len(user_vecs))

# ----------------------------
# Match
# ----------------------------
matches = []
unmatched = 0
bad_format = 0

for i, vraw in enumerate(user_vecs, start=1):
    v = parse_vector_cell(vraw) if not isinstance(vraw, (list, tuple)) else list(vraw)
    parsed = ensure_minmax_coeffs(v)

    if parsed is None:
        bad_format += 1
        matches.append({"index": i, "status": "bad_format_expected_[min,max,coeffs...]", "input": vraw, "candidates": []})
        continue

    mn, mx, coeffs = parsed
    sp = span_abs(mn, mx)

    key = (sp, canon_coeff_key(coeffs))
    cand = lookup.get(key, [])

    if not cand:
        unmatched += 1
        matches.append({
            "index": i,
            "status": "no_match",
            "input_min": mn,
            "input_max": mx,
            "input_span_abs": sp,
            "input_coeffs": coeffs,
            "candidates": [],
        })
    else:
        seen = set()
        out = []
        for c in cand:
            tup = (c["knot"], str(c["unknotting_number"]), c["mirror"])
            if tup in seen:
                continue
            seen.add(tup)
            out.append({
                "knot": c["knot"],
                "unknotting_number": c["unknotting_number"],
                "mirror": c["mirror"],
                "source_col": c["source_col"],
                "knotinfo_min": c["knotinfo_min"],
                "knotinfo_max": c["knotinfo_max"],
            })
        matches.append({
            "index": i,
            "status": "matched",
            "input_min": mn,
            "input_max": mx,
            "input_span_abs": sp,
            "input_coeffs": coeffs,
            "candidates": out,
        })

print(f"Matched {len(user_vecs)-unmatched-bad_format}/{len(user_vecs)} vectors; unmatched={unmatched}, bad_format={bad_format}")

# ----------------------------
# Extract unknotting numbers "whenever applicable"
# ----------------------------
summary = []
for m in matches:
    if m["status"] != "matched":
        summary.append({"index": m["index"], "unknotting_numbers": [], "note": m["status"]})
        continue
    uvals = []
    for c in m["candidates"]:
        u = c["unknotting_number"]
        if u is None or (isinstance(u, float) and pd.isna(u)):
            continue
        uvals.append(u)
    # de-dup
    seen = set()
    uuniq = []
    for u in uvals:
        su = str(u)
        if su in seen:
            continue
        seen.add(su)
        uuniq.append(u)
    summary.append({"index": m["index"], "unknotting_numbers": uuniq, "n_candidates": len(m["candidates"])})

print("\n=== Unknotting number candidates (per input vector) ===")
for s in summary:
    print(f"#{s['index']:>3}: u candidates = {s.get('unknotting_numbers')}  (note={s.get('note','')})")

# ----------------------------
# Save outputs to OUT_DIR (deterministic)
# ----------------------------
out_matches_jsonl = os.path.join(OUT_DIR, "knotinfo_match_results.jsonl")
out_summary_jsonl = os.path.join(OUT_DIR, "knotinfo_unknotting_candidates.jsonl")

with open(out_matches_jsonl, "w") as f:
    for m in matches:
        f.write(json.dumps(m) + "\n")
print("\nWrote detailed match results to:", out_matches_jsonl)

with open(out_summary_jsonl, "w") as f:
    for s in summary:
        f.write(json.dumps(s) + "\n")
print("Wrote unknotting-number summary to:", out_summary_jsonl)

# %%
import glob, ast, re

# --- your target KnotInfo-style vector ---
target_vec = [-7, 2, -2, 4, -6, 9, -9, 9, -8, 6, -3, 1]
target_coeffs = target_vec[2:]
target_coeffs_mirror = list(reversed(target_coeffs))

def extract_first_int_list(line: str):
    """
    Extract the first [...] from a line and parse it as a Python list of ints.
    Works even if the line contains other text/columns.
    """
    m = re.search(r"\[[^\]]+\]", line)
    if not m:
        return None
    s = m.group(0)
    try:
        v = ast.literal_eval(s)
    except Exception:
        return None
    if not isinstance(v, list) or not all(isinstance(x, int) for x in v):
        return None
    return v

# pick newest vector file (same naming pattern your notebook uses)
paths = sorted(glob.glob(f"{OUT_DIR}/min_pd_results_flips*_jones_vec_knotinfo.txt"))
if not paths:
    raise FileNotFoundError(f"No min_pd_results_flips*_jones_vec_knotinfo.txt found in OUT_DIR={OUT_DIR}")
path = paths[-1]
print("Searching in:", path)

hits = []
with open(path, "r", encoding="utf-8") as f:
    for lineno, line in enumerate(f, 1):
        v = extract_first_int_list(line.strip())
        if v is None:
            continue

        # Accept either:
        #  - full KnotInfo vector: [min,max,c...,c]
        #  - coefficients-only vector: [c...,c]
        if len(v) >= 3 and isinstance(v[0], int) and isinstance(v[1], int):
            coeffs = v[2:]
        else:
            coeffs = v

        if coeffs == target_coeffs:
            hits.append((lineno, "direct (up to q-shift)"))
        elif coeffs == target_coeffs_mirror:
            hits.append((lineno, "mirror (up to q-shift)"))

if hits:
    print(f"FOUND {len(hits)} match(es):")
    for lineno, kind in hits[:50]:
        print(f"  line {lineno}: {kind}")
else:
    print("No match (even up to mirror + q-shift).")
